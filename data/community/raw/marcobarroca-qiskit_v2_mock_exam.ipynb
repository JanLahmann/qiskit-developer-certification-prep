# %% [markdown]
# # Qiskit v2.x Mock Exam
#
# This notebook contains one 68-question mock test for Qiskit v2.x exam practice.
#
# - Questions: 68
# - Suggested time: 90 minutes
# - Practice passing target: 47 correct answers
# - Optional scratch code cells: 28
#
# The scratch cells do not require live IBM Quantum credentials. Runtime questions are written so they can be reasoned about locally.
#
# Answers are collapsed below each question. Keep them closed while solving if you want exam-style practice.

# %%
# Optional environment check.
try:
    import qiskit
    print("Qiskit version:", qiskit.__version__)
except Exception as exc:
    print("Qiskit is not installed in this kernel:", exc)

# %% [markdown]
# ### Question 1
#
#
# A primitive is needed for sampled measurement data rather than expectation values. What does `SamplerV2` return from measured circuits?
#
#
# - **A.** Observable expectation values
# - **B.** A final statevector
# - **C.** A backend configuration document
# - **D.** Classical-register bitstring samples/count-access data

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# Sampler is the primitive for sampled classical measurement data. Estimator returns expectation values.
#
# **Choice review**
#
# - **A: Not correct.** Expectation values are returned by Estimator-style primitives; Sampler returns sampled classical-register data. _Choice text:_ Observable expectation values
# - **B: Not correct.** Sampler does not return a final statevector. It samples measurements and exposes classical-register data. _Choice text:_ A final statevector
# - **C: Not correct.** A backend configuration describes hardware/backend properties. It is not the sampled measurement payload returned by Sampler. _Choice text:_ A backend configuration document
# - **D: Correct.** Sampler is the primitive for sampled classical measurement data. Estimator returns expectation values. _Choice text:_ Classical-register bitstring samples/count-access data
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.SamplerPubResult](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.SamplerPubResult)
#
# </details>

# %% [markdown]
# ### Question 2
#
#
# Which line changes a `ParameterVector` named `theta` from length 2 to length 6?
#
#
# - **A.** `theta.extend(6)`
# - **B.** `theta.adjust(6)`
# - **C.** `theta.resize(6)`
# - **D.** `theta.length = 6`

# %%
# Optional scratch cell for Question Q002
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.circuit import ParameterVector

v = ParameterVector("theta", 2)
print(len(v), list(v))
v.resize(4)
print(len(v), list(v))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# `ParameterVector.resize()` is the documented method for changing the vector length.
#
# **Choice review**
#
# - **A: Not correct.** That method name is not the documented `ParameterVector` resizing API; the supported method is `resize(...)`. _Choice text:_ `theta.extend(6)`
# - **B: Not correct.** That method name is not the documented `ParameterVector` resizing API; the supported method is `resize(...)`. _Choice text:_ `theta.adjust(6)`
# - **C: Correct.** `ParameterVector.resize()` is the documented method for changing the vector length. _Choice text:_ `theta.resize(6)`
# - **D: Not correct.** `ParameterVector` length is not changed by assigning to a `.length` attribute; use `resize(...)`. _Choice text:_ `theta.length = 6`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter)
#
# </details>

# %% [markdown]
# ### Question 3
#
#
# **Select 3.**
#
# A usage report is being interpreted for Runtime work. Which statements are accurate?
#
#
# - [ ] **A.** Batch usage is local Python CPU time.
# - [ ] **B.** `batch.usage_time()` is the documented SDK call.
# - [ ] **C.** The API token changes how usage time is computed.
# - [ ] **D.** Single-job usage is quantum time charged for processing that job.
# - [ ] **E.** Session usage is tied to the active session workload window under Runtime accounting.
# - [ ] **F.** Reported details data can include a `usage_time` field.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D, E, F
#
# Usage time is Runtime quantum-usage accounting, not local CPU time. Reported details metadata exposes usage fields; the distractor method is not the documented pattern.
#
# **Choice review**
#
# - **A: Not correct.** Runtime usage time is service-side quantum usage accounting. It is not local CPU time, token-dependent, or retrieved through that nonexistent method. _Choice text:_ Batch usage is local Python CPU time.
# - **B: Not correct.** Runtime usage time is service-side quantum usage accounting. It is not local CPU time, token-dependent, or retrieved through that nonexistent method. _Choice text:_ `batch.usage_time()` is the documented SDK call.
# - **C: Not correct.** Runtime usage time is service-side quantum usage accounting. It is not local CPU time, token-dependent, or retrieved through that nonexistent method. _Choice text:_ The API token changes how usage time is computed.
# - **D: Correct.** Usage time is Runtime quantum-usage accounting, not local CPU time. Reported details metadata exposes usage fields; the distractor method is not the documented pattern. _Choice text:_ Single-job usage is quantum time charged for processing that job.
# - **E: Correct.** Usage time is Runtime quantum-usage accounting, not local CPU time. Reported details metadata exposes usage fields; the distractor method is not the documented pattern. _Choice text:_ Session usage is tied to the active session workload window under Runtime accounting.
# - **F: Correct.** Usage time is Runtime quantum-usage accounting, not local CPU time. Reported details metadata exposes usage fields; the distractor method is not the documented pattern. _Choice text:_ Reported details data can include a `usage_time` field.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execution-modes](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-runtime-rest](https://quantum.cloud.ibm.com/docs/en/api/qiskit-runtime-rest)
#
# </details>

# %% [markdown]
# ### Question 4
#
#
# Using Qiskit's displayed state-label ordering, what final basis state is prepared by this circuit?
#
# ```python
# from qiskit import QuantumCircuit
#
# qc = QuantumCircuit(3)
# qc.x(2)
# qc.cx(2, 0)
# qc.x(1)
# qc.cx(1, 2)
# ```
#
#
# - **A.** `|011>`
# - **B.** `|110>`
# - **C.** `|101>`
# - **D.** `|111>`

# %%
# Optional scratch cell for Question Q004
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(3)
qc.x(2)
qc.cx(2, 0)
qc.x(1)
qc.cx(1, 2)
print(Statevector.from_instruction(qc))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Track qubits by index first: q2 is set to 1, q0 flips to 1, q1 is set to 1, then q1 controls a flip on q2 back to 0. Qiskit labels display q2 q1 q0, so the state is `|011>`.
#
# **Choice review**
#
# - **A: Correct.** Track qubits by index first: q2 is set to 1, q0 flips to 1, q1 is set to 1, then q1 controls a flip on q2 back to 0. Qiskit labels display q2 q1 q0, so the state is `|011>`. _Choice text:_ `|011>`
# - **B: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ `|110>`
# - **C: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ `|101>`
# - **D: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ `|111>`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 5
#
#
# **Select 2.**
#
# Which `SamplerV2` option groups configure suppression or mitigation behavior?
#
#
# - [ ] **A.** `sampler.options.twirling`
# - [ ] **B.** `sampler.options.dynamical_decoupling`
# - [ ] **C.** `sampler.options.surface_codes`
# - [ ] **D.** `sampler.options.max_execution_time`
# - [ ] **E.** `sampler.options.account_token`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A, B
#
# `twirling` and `dynamical_decoupling` are the relevant Sampler option groups here. The other paths are not the v2 options being tested.
#
# **Choice review**
#
# - **A: Correct.** `twirling` and `dynamical_decoupling` are the relevant Sampler option groups here. The other paths are not the v2 options being tested. _Choice text:_ `sampler.options.twirling`
# - **B: Correct.** `twirling` and `dynamical_decoupling` are the relevant Sampler option groups here. The other paths are not the v2 options being tested. _Choice text:_ `sampler.options.dynamical_decoupling`
# - **C: Not correct.** `surface_codes` is not the Sampler v2 option group used for the suppression/mitigation behavior tested here. _Choice text:_ `sampler.options.surface_codes`
# - **D: Not correct.** `max_execution_time` can bound execution time, but it is not an error-suppression or mitigation option group. _Choice text:_ `sampler.options.max_execution_time`
# - **E: Not correct.** Authentication/account tokens are not Sampler mitigation options. _Choice text:_ `sampler.options.account_token`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options)
# - [https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques](https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques)
#
# </details>

# %% [markdown]
# ### Question 6
#
#
# A qubit is initialized with amplitudes `[sqrt(3)/2, 1/2]`. Which Bloch-vector panel represents the state?
#
# ![Question figure](../assets/visuals/bloch_panels.png)
#
#
# - **A.** Panel A
# - **B.** Panel B
# - **C.** Panel C
# - **D.** Panel D

# %%
# Optional scratch cell for Question Q006
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.visualization import plot_bloch_vector

plot_bloch_vector([3**0.5 / 2, 0, 0.5])

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# For real amplitudes `a|0> + b|1>`, the Bloch vector is `(2ab, 0, a^2-b^2)`. With `a=sqrt(3)/2` and `b=1/2`, that is approximately `(0.866, 0, 0.5)`, shown in panel C.
#
# **Choice review**
#
# - **A: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel A
# - **B: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel B
# - **C: Correct.** For real amplitudes `a|0> + b|1>`, the Bloch vector is `(2ab, 0, a^2-b^2)`. With `a=sqrt(3)/2` and `b=1/2`, that is approximately `(0.866, 0, 0.5)`, shown in panel C. _Choice text:_ Panel C
# - **D: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel D
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_bloch_multivector](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_bloch_multivector)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization](https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization)
#
# </details>

# %% [markdown]
# ### Question 7
#
#
# In a `CircuitInstruction`, which object is the operation component?
#
#
# - **A.** A backend options dictionary
# - **B.** A `Gate` or `Instruction` applied to bits
# - **C.** A `SamplerV2` primitive object
# - **D.** A Runtime session identifier

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# A `CircuitInstruction` combines an operation with qubit and optional clbit operands. Runtime primitives and sessions are outside the circuit instruction model.
#
# **Choice review**
#
# - **A: Not correct.** This object is outside the circuit-instruction model. A `CircuitInstruction` operation is a gate/instruction applied to bits. _Choice text:_ A backend options dictionary
# - **B: Correct.** A `CircuitInstruction` combines an operation with qubit and optional clbit operands. Runtime primitives and sessions are outside the circuit instruction model. _Choice text:_ A `Gate` or `Instruction` applied to bits
# - **C: Not correct.** This object is outside the circuit-instruction model. A `CircuitInstruction` operation is a gate/instruction applied to bits. _Choice text:_ A `SamplerV2` primitive object
# - **D: Not correct.** This object is outside the circuit-instruction model. A `CircuitInstruction` operation is a gate/instruction applied to bits. _Choice text:_ A Runtime session identifier
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 8
#
#
# Which code fragment is valid and applies the `Unroll3qOrMore` transpiler pass to a circuit named `qc`?
#
#
# - **A.**
#
#     ```python
#     from qiskit.transpiler import PassManager
#     from qiskit.transpiler.passes import Unroll3qOrMore
#     qc = PassManager([Unroll3qOrMore()]).run(qc)
#     ```
# - **B.** `qc = qc.unroll3qOrMore()`
# - **C.** `qc = Unroll3qOrMore().execute(qc)`
# - **D.** `qc.apply_pass(Unroll3qOrMore())`

# %%
# Optional scratch cell for Question Q008
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.circuit.random import random_circuit
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroll3qOrMore

qc = random_circuit(4, 4, seed=7)
qc = PassManager([Unroll3qOrMore()]).run(qc)
print(qc.count_ops())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Transpiler passes are run through a `PassManager`. The distractors use method names that look plausible but are not the Qiskit pass-manager API.
#
# **Choice review**
#
# - **A: Correct.** Transpiler passes are run through a `PassManager`. The distractors use method names that look plausible but are not the Qiskit pass-manager API.
#
#   Choice text:
#
#     ```python
#     from qiskit.transpiler import PassManager
#     from qiskit.transpiler.passes import Unroll3qOrMore
#     qc = PassManager([Unroll3qOrMore()]).run(qc)
#     ```
# - **B: Not correct.** Transpiler passes are not called as ad hoc circuit methods; they are run through a `PassManager`. _Choice text:_ `qc = qc.unroll3qOrMore()`
# - **C: Not correct.** Transpiler passes are not called as ad hoc circuit methods; they are run through a `PassManager`. _Choice text:_ `qc = Unroll3qOrMore().execute(qc)`
# - **D: Not correct.** Transpiler passes are not called as ad hoc circuit methods; they are run through a `PassManager`. _Choice text:_ `qc.apply_pass(Unroll3qOrMore())`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/transpile-with-pass-managers](https://quantum.cloud.ibm.com/docs/en/guides/transpile-with-pass-managers)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/transpiler_passes](https://quantum.cloud.ibm.com/docs/en/api/qiskit/transpiler_passes)
#
# </details>

# %% [markdown]
# ### Question 9
#
#
# A sampler PUB is submitted without its own shot override. The notebook contains this setup:
#
# ```python
# sampler = SamplerV2(mode=backend)
# sampler.options.default_shots = 2048
# ```
#
#
# - **A.** The primitive creates 2048 twirled circuits before sampling.
# - **B.** Each measured qubit is read 2048 times before circuit execution begins.
# - **C.** The backend is reserved for exactly 2048 seconds.
# - **D.** The PUB is sampled with 2048 shots unless the PUB supplies a different shot count.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `default_shots` is the fallback shot count for Sampler PUBs. It does not configure twirling, per-qubit pre-measurement, or reservation time.
#
# **Choice review**
#
# - **A: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ The primitive creates 2048 twirled circuits before sampling.
# - **B: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ Each measured qubit is read 2048 times before circuit execution begins.
# - **C: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ The backend is reserved for exactly 2048 seconds.
# - **D: Correct.** `default_shots` is the fallback shot count for Sampler PUBs. It does not configure twirling, per-qubit pre-measurement, or reservation time. _Choice text:_ The PUB is sampled with 2048 shots unless the PUB supplies a different shot count.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2)
#
# </details>

# %% [markdown]
# ### Question 10
#
#
# A Runtime session is being opened for hardware work. Which value belongs in the session setup rather than in circuit construction or authentication?
#
#
# - **A.** The account password in plain text
# - **B.** An infinite maximum lifetime
# - **C.** The backend or execution mode
# - **D.** The circuit's qubit count

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Sessions are associated with an execution context such as a backend/mode. Circuit width and credentials are handled elsewhere, and service limits govern lifetime.
#
# **Choice review**
#
# - **A: Not correct.** Plain-text account passwords are not a Runtime session construction setting. _Choice text:_ The account password in plain text
# - **B: Not correct.** Runtime sessions are governed by service-side maximum-time and inactivity limits, not an infinite lifetime. _Choice text:_ An infinite maximum lifetime
# - **C: Correct.** Sessions are associated with an execution context such as a backend/mode. Circuit width and credentials are handled elsewhere, and service limits govern lifetime. _Choice text:_ The backend or execution mode
# - **D: Not correct.** Circuit width is defined by the `QuantumCircuit`, not by Runtime session setup. _Choice text:_ The circuit's qubit count
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execution-modes](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
# - [https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session](https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session)
#
# </details>

# %% [markdown]
# ### Question 11
#
#
# Which construction line puts `EstimatorV2` in a valid execution context?
#
#
# - **A.** `estimator = EstimatorV2(mode=sampler)`
# - **B.** `estimator = EstimatorV2(mode=backend)`
# - **C.** `estimator = EstimatorV2(mode=observable)`
# - **D.** `estimator = EstimatorV2(mode=circuit)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# The primitive mode is an execution context such as a backend, session, or batch. Circuits and observables are supplied later as PUB data.
#
# **Choice review**
#
# - **A: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ `estimator = EstimatorV2(mode=sampler)`
# - **B: Correct.** The primitive mode is an execution context such as a backend, session, or batch. Circuits and observables are supplied later as PUB data. _Choice text:_ `estimator = EstimatorV2(mode=backend)`
# - **C: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ `estimator = EstimatorV2(mode=observable)`
# - **D: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ `estimator = EstimatorV2(mode=circuit)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options)
#
# </details>

# %% [markdown]
# ### Question 12
#
#
# Given a pass manager with basis gates `['ecr', 'rz', 'sx', 'x']`, which panel is a plausible transpiled drawing of an H-CX circuit?
#
# ![Question figure](../assets/visuals/transpiled_panels.png)
#
#
# - **A.** Panel A
# - **B.** Panel B
# - **C.** Panel C
# - **D.** Panel D

# %%
# Optional scratch cell for Question Q012
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit, generate_preset_pass_manager

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
pass_manager = generate_preset_pass_manager(
    optimization_level=3,
    basis_gates=["ecr", "rz", "sx", "x"],
)
tqc = pass_manager.run(qc)
tqc.draw(output="mpl", idle_wires=False)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# The correct panel uses only the requested basis gates and decomposes the high-level operations. Panels retaining H/CX or using a different two-qubit basis do not match.
#
# **Choice review**
#
# - **A: Correct.** The correct panel uses only the requested basis gates and decomposes the high-level operations. Panels retaining H/CX or using a different two-qubit basis do not match. _Choice text:_ Panel A
# - **B: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel B
# - **C: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel C
# - **D: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel D
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/visualize-circuits](https://quantum.cloud.ibm.com/docs/en/guides/visualize-circuits)
# - [https://quantum.cloud.ibm.com/docs/en/guides/transpile-with-pass-managers](https://quantum.cloud.ibm.com/docs/en/guides/transpile-with-pass-managers)
#
# </details>

# %% [markdown]
# ### Question 13
#
#
# A ZNE configuration is being reviewed. Which assignment uses the expected value type for noise amplification factors?
#
#
# - **A.** `estimator.options.resilience.zne.noise_factors = 'linear'`
# - **B.** `estimator.options.resilience.zne.noise_factors = (-1, 1, 3)`
# - **C.** `estimator.options.resilience.zne.noise_factors = {'low': 1, 'high': 3}`
# - **D.** `estimator.options.resilience.zne.noise_factors = (1, 2, 4)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# ZNE noise factors are positive numeric amplification factors supplied as a sequence. Strategy names, negative values, and dictionaries are not the expected option value.
#
# **Choice review**
#
# - **A: Not correct.** A string strategy name is not a numeric list of ZNE amplification factors. _Choice text:_ `estimator.options.resilience.zne.noise_factors = 'linear'`
# - **B: Not correct.** ZNE noise factors are positive amplification factors; negative factors are invalid. _Choice text:_ `estimator.options.resilience.zne.noise_factors = (-1, 1, 3)`
# - **C: Not correct.** The option expects a sequence of numeric amplification factors, not a dictionary keyed by labels. _Choice text:_ `estimator.options.resilience.zne.noise_factors = {'low': 1, 'high': 3}`
# - **D: Correct.** ZNE noise factors are positive numeric amplification factors supplied as a sequence. Strategy names, negative values, and dictionaries are not the expected option value. _Choice text:_ `estimator.options.resilience.zne.noise_factors = (1, 2, 4)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-zne-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-zne-options)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options)
#
# </details>

# %% [markdown]
# ### Question 14
#
#
# A workload should use the preset mitigation behavior that includes ZNE. Which assignment selects that resilience level?
#
#
# - **A.** `estimator.options.resilience_level = 0`
# - **B.** `estimator.options.resilience_level = -1`
# - **C.** `estimator.options.resilience_level = 2`
# - **D.** `estimator.options.resilience_level = 1`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Runtime Estimator resilience level 2 enables ZNE-based mitigation behavior. Level 0 has no resilience, level 1 is lower-level mitigation behavior, and negative values are invalid.
#
# **Choice review**
#
# - **A: Not correct.** This level does not select the ZNE preset being tested. Level 2 is the Runtime Estimator level associated with ZNE behavior. _Choice text:_ `estimator.options.resilience_level = 0`
# - **B: Not correct.** This level does not select the ZNE preset being tested. Level 2 is the Runtime Estimator level associated with ZNE behavior. _Choice text:_ `estimator.options.resilience_level = -1`
# - **C: Correct.** Runtime Estimator resilience level 2 enables ZNE-based mitigation behavior. Level 0 has no resilience, level 1 is lower-level mitigation behavior, and negative values are invalid. _Choice text:_ `estimator.options.resilience_level = 2`
# - **D: Not correct.** This level does not select the ZNE preset being tested. Level 2 is the Runtime Estimator level associated with ZNE behavior. _Choice text:_ `estimator.options.resilience_level = 1`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-resilience-options-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-resilience-options-v2)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-zne-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-zne-options)
#
# </details>

# %% [markdown]
# ### Question 15
#
#
# A sampler job was run for a circuit that measured classical register `creg`. Which line can return a counts dictionary from the first PUB result?
#
#
# - **A.** `job.result().metadata.counts(creg)`
# - **B.** `job.result()[0].data.creg.get_counts()`
# - **C.** `job.get_counts(creg)`
# - **D.** `job.result(creg).to_counts_dict()`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# SamplerV2 returns PUB results. Classical register data is accessed through `result()[0].data.<register>`, and that register data exposes `get_counts()`.
#
# **Choice review**
#
# - **A: Not correct.** That follows an old or nonexistent result path. Sampler v2 counts are under the first PUB result's classical-register data, then `get_counts()`. _Choice text:_ `job.result().metadata.counts(creg)`
# - **B: Correct.** SamplerV2 returns PUB results. Classical register data is accessed through `result()[0].data.<register>`, and that register data exposes `get_counts()`. _Choice text:_ `job.result()[0].data.creg.get_counts()`
# - **C: Not correct.** That follows an old or nonexistent result path. Sampler v2 counts are under the first PUB result's classical-register data, then `get_counts()`. _Choice text:_ `job.get_counts(creg)`
# - **D: Not correct.** That follows an old or nonexistent result path. Sampler v2 counts are under the first PUB result's classical-register data, then `get_counts()`. _Choice text:_ `job.result(creg).to_counts_dict()`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.SamplerPubResult](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.SamplerPubResult)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2)
#
# </details>

# %% [markdown]
# ### Question 16
#
#
# **Select 2.**
#
# Which fragments create a circuit with 5 qubits and 2 classical bits?
#
#
# - [ ] **A.** `QuantumCircuit(QuantumRegister(5, 'q'), ClassicalRegister(2, 'c'))`
# - [ ] **B.** `QuantumCircuit(2, 5)`
# - [ ] **C.** `QuantumCircuit(QuantumRegister(5), QuantumRegister(2))`
# - [ ] **D.** `QuantumCircuit(ClassicalRegister(2), QuantumRegister(5))`
# - [ ] **E.** `QuantumCircuit(5, 2)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A, E
#
# The integer constructor uses qubits first and classical bits second. With explicit registers, qubits must come from `QuantumRegister` and classical bits from `ClassicalRegister`.
#
# **Choice review**
#
# - **A: Correct.** The integer constructor uses qubits first and classical bits second. With explicit registers, qubits must come from `QuantumRegister` and classical bits from `ClassicalRegister`. _Choice text:_ `QuantumCircuit(QuantumRegister(5, 'q'), ClassicalRegister(2, 'c'))`
# - **B: Not correct.** The integer constructor is ordered as qubits first, classical bits second; this swaps the requested sizes. _Choice text:_ `QuantumCircuit(2, 5)`
# - **C: Not correct.** Two quantum registers do not create classical bits. The requested classical storage must use `ClassicalRegister` or the second integer argument. _Choice text:_ `QuantumCircuit(QuantumRegister(5), QuantumRegister(2))`
# - **D: Not correct.** This places the classical register before the quantum register in a way that does not match the requested circuit construction. _Choice text:_ `QuantumCircuit(ClassicalRegister(2), QuantumRegister(5))`
# - **E: Correct.** The integer constructor uses qubits first and classical bits second. With explicit registers, qubits must come from `QuantumRegister` and classical bits from `ClassicalRegister`. _Choice text:_ `QuantumCircuit(5, 2)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 17
#
#
# For Estimator, which tuple has the shape of a primitive unified bloc rather than a local plotting or serialization object?
#
#
# - **A.** `(counts, legend, title)`
# - **B.** `(qasm_source, filename)`
# - **C.** `(backend_name, api_token)`
# - **D.** `(isa_circuit, isa_observables, parameter_values)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# An Estimator PUB packages a circuit together with observables and optional parameter values/precision. Plotting data, QASM filenames, and credentials are not PUBs.
#
# **Choice review**
#
# - **A: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(counts, legend, title)`
# - **B: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(qasm_source, filename)`
# - **C: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(backend_name, api_token)`
# - **D: Correct.** An Estimator PUB packages a circuit together with observables and optional parameter values/precision. Plotting data, QASM filenames, and credentials are not PUBs. _Choice text:_ `(isa_circuit, isa_observables, parameter_values)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 18
#
#
# The following one-qubit circuit is sampled many times. What is the expected probability of bit value 0?
#
# ```python
# from qiskit import QuantumCircuit
# import numpy as np
#
# qc = QuantumCircuit(1)
# qc.reset(0)
# qc.ry(2 * np.pi / 3, 0)
# qc.measure_all()
# ```
#
#
# - **A.** `0.50`
# - **B.** `1.00`
# - **C.** `0.25`
# - **D.** `0.75`

# %%
# Optional scratch cell for Question Q018
# Run this if you want to inspect the relevant Qiskit behavior locally.
import numpy as np

theta = 2 * np.pi / 3
print("P(0) =", np.cos(theta / 2) ** 2)
print("P(1) =", np.sin(theta / 2) ** 2)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# For `RY(theta)|0>`, the probability of measuring 0 is `cos^2(theta/2)`. With `theta = 2*pi/3`, this is `cos^2(pi/3) = 0.25`.
#
# **Choice review**
#
# - **A: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RY(theta)|0>`, the probability of measuring 0 is `cos^2(theta/2)`. With `theta = 2*pi/3`, this is `cos^2(pi/3) = 0.25`. _Choice text:_ `0.50`
# - **B: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RY(theta)|0>`, the probability of measuring 0 is `cos^2(theta/2)`. With `theta = 2*pi/3`, this is `cos^2(pi/3) = 0.25`. _Choice text:_ `1.00`
# - **C: Correct.** For `RY(theta)|0>`, the probability of measuring 0 is `cos^2(theta/2)`. With `theta = 2*pi/3`, this is `cos^2(pi/3) = 0.25`. _Choice text:_ `0.25`
# - **D: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RY(theta)|0>`, the probability of measuring 0 is `cos^2(theta/2)`. With `theta = 2*pi/3`, this is `cos^2(pi/3) = 0.25`. _Choice text:_ `0.75`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library](https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library)
#
# </details>

# %% [markdown]
# ### Question 19
#
#
# Which object category can be passed as `mode` when constructing a `SamplerV2` primitive?
#
#
# - **A.** A raw Pauli string such as `'ZZ'`
# - **B.** A backend, session, or batch execution context
# - **C.** A `QuantumCircuit` to be sampled
# - **D.** A `SparsePauliOp` observable

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `mode` selects where/how the primitive runs. Circuits and observables are PUB inputs, not primitive modes.
#
# **Choice review**
#
# - **A: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ A raw Pauli string such as `'ZZ'`
# - **B: Correct.** `mode` selects where/how the primitive runs. Circuits and observables are PUB inputs, not primitive modes. _Choice text:_ A backend, session, or batch execution context
# - **C: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ A `QuantumCircuit` to be sampled
# - **D: Not correct.** Primitive `mode` is the execution context. Circuits, observables, Sampler objects, and raw Pauli strings belong elsewhere in the workflow. _Choice text:_ A `SparsePauliOp` observable
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2)
#
# </details>

# %% [markdown]
# ### Question 20
#
#
# Ignoring global phase, which Pauli operator matches the one-qubit unitary below?
#
# ```python
# qc = QuantumCircuit(1)
# qc.z(0)
# qc.x(0)
# qc.z(0)
# ```
#
#
# - **A.** `Pauli('X')`
# - **B.** `Pauli('Z')`
# - **C.** `Pauli('Y')`
# - **D.** No valid Pauli operator

# %%
# Optional scratch cell for Question Q020
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit.quantum_info import Operator

qc = QuantumCircuit(1)
qc.z(0)
qc.x(0)
qc.z(0)
print(Operator(qc).data)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# The product `Z X Z` is `-X`. Since the question ignores global phase, the matching Pauli axis is X.
#
# **Choice review**
#
# - **A: Correct.** The product `Z X Z` is `-X`. Since the question ignores global phase, the matching Pauli axis is X. _Choice text:_ `Pauli('X')`
# - **B: Not correct.** This is the wrong Pauli axis after simplifying the gate product up to global phase. _Choice text:_ `Pauli('Z')`
# - **C: Not correct.** This is the wrong Pauli axis after simplifying the gate product up to global phase. _Choice text:_ `Pauli('Y')`
# - **D: Not correct.** This is the wrong Pauli axis after simplifying the gate product up to global phase. _Choice text:_ No valid Pauli operator
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 21
#
#
# The circuit below stores samples in a two-bit classical register. Which count dictionary has the correct key width for this workload?
#
# ```python
# q = QuantumRegister(2, 'q')
# c = ClassicalRegister(2, 'c')
# qc = QuantumCircuit(q, c)
# qc.h(0)
# qc.measure(0, 0)
# with qc.while_loop((c[0], 1)):
#     qc.x(1)
#     qc.measure(1, 1)
#     qc.measure(0, 0)
# ```
#
#
# - **A.** `{'000': 1024}`
# - **B.** `{'0': 512, '1': 512}`
# - **C.** `NameError: name 'while_loop' is not defined`
# - **D.** `{'00': 430, '10': 594}`

# %%
# Optional scratch cell for Question Q021
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister

q = QuantumRegister(2, "q")
c = ClassicalRegister(2, "c")
qc = QuantumCircuit(q, c)
qc.h(0)
qc.measure(0, 0)
with qc.while_loop((c[0], 1)):
    qc.x(1)
    qc.measure(1, 1)
    qc.measure(0, 0)

qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# The circuit has a two-bit classical register, so count keys are two-bit strings. `while_loop` is a Qiskit circuit control-flow builder, not a Python name error.
#
# **Choice review**
#
# - **A: Not correct.** The key width must match the classical register width in the circuit; this option uses the wrong number of classical bits. _Choice text:_ `{'000': 1024}`
# - **B: Not correct.** The key width must match the classical register width in the circuit; this option uses the wrong number of classical bits. _Choice text:_ `{'0': 512, '1': 512}`
# - **C: Not correct.** `while_loop` is a Qiskit circuit method in this context, so the issue is not a Python `NameError`. _Choice text:_ `NameError: name 'while_loop' is not defined`
# - **D: Correct.** The circuit has a two-bit classical register, so count keys are two-bit strings. `while_loop` is a Qiskit circuit control-flow builder, not a Python name error. _Choice text:_ `{'00': 430, '10': 594}`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow](https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 22
#
#
# A hardware workload shows coherent over-rotation effects. Which option names the noise class that Pauli twirling is designed to reshape statistically?
#
#
# - **A.** HTTP retry noise
# - **B.** Classical register overflow
# - **C.** Coherent gate noise
# - **D.** Finite-shot sampling noise

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Pauli twirling randomizes coherent gate errors into stochastic Pauli-like noise, which is easier to average or mitigate.
#
# **Choice review**
#
# - **A: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ HTTP retry noise
# - **B: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ Classical register overflow
# - **C: Correct.** Pauli twirling randomizes coherent gate errors into stochastic Pauli-like noise, which is easier to average or mitigate. _Choice text:_ Coherent gate noise
# - **D: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ Finite-shot sampling noise
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options)
# - [https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques](https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques)
#
# </details>

# %% [markdown]
# ### Question 23
#
#
# Which import path is correct for transpiler passes such as `SabreLayout` and `RemoveFinalReset`?
#
#
# - **A.** `from qiskit.scheduler import SabreLayout, RemoveFinalReset`
# - **B.** `from qiskit.transpiler.passes import SabreLayout, RemoveFinalReset`
# - **C.** `from qiskit.circuit.library import SabreLayout, RemoveFinalReset`
# - **D.** `from qiskit.providers.models import SabreLayout, RemoveFinalReset`

# %%
# Optional scratch cell for Question Q023
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.transpiler.passes import BasisTranslator, RemoveFinalReset, SabreLayout

print(RemoveFinalReset.__module__)
print(SabreLayout.__module__)
print(BasisTranslator.__module__)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# These classes are transpiler passes, so they are imported from `qiskit.transpiler.passes`.
#
# **Choice review**
#
# - **A: Not correct.** `qiskit.scheduler` is not the module for these transpiler pass classes. _Choice text:_ `from qiskit.scheduler import SabreLayout, RemoveFinalReset`
# - **B: Correct.** These classes are transpiler passes, so they are imported from `qiskit.transpiler.passes`. _Choice text:_ `from qiskit.transpiler.passes import SabreLayout, RemoveFinalReset`
# - **C: Not correct.** `qiskit.circuit.library` contains circuits/gates, not transpiler pass classes such as `SabreLayout`. _Choice text:_ `from qiskit.circuit.library import SabreLayout, RemoveFinalReset`
# - **D: Not correct.** Provider model classes are not where Qiskit transpiler passes are imported from. _Choice text:_ `from qiskit.providers.models import SabreLayout, RemoveFinalReset`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/transpiler_passes](https://quantum.cloud.ibm.com/docs/en/api/qiskit/transpiler_passes)
#
# </details>

# %% [markdown]
# ### Question 24
#
#
# What does this OpenQASM 3 declaration create?
#
# ```qasm
# uint[16] counter;
# ```
#
#
# - **A.** It declares a unsigned 16-bit integer.
# - **B.** It indexes the eighth element of an array.
# - **C.** It assigns the value inside brackets to the identifier.
# - **D.** It declares a Python integer and exports it to Qiskit.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# In OpenQASM 3, the bracket after scalar types such as `int`, `uint`, `bit`, and `angle` is the type width or register size, not an assigned value.
#
# **Choice review**
#
# - **A: Correct.** In OpenQASM 3, the bracket after scalar types such as `int`, `uint`, `bit`, and `angle` is the type width or register size, not an assigned value. _Choice text:_ It declares a unsigned 16-bit integer.
# - **B: Not correct.** The bracket in this declaration gives a type width or register size; it is not indexing into an existing array. _Choice text:_ It indexes the eighth element of an array.
# - **C: Not correct.** This is a declaration, not an assignment. The bracketed value describes width/size. _Choice text:_ It assigns the value inside brackets to the identifier.
# - **D: Not correct.** OpenQASM declarations are source-language declarations, not Python integer exports. _Choice text:_ It declares a Python integer and exports it to Qiskit.
#
# **References**
#
# - [https://openqasm.com/versions/3.0/language/types.html](https://openqasm.com/versions/3.0/language/types.html)
#
# </details>

# %% [markdown]
# ### Question 25
#
#
# Which code fragment is valid and creates a one-qubit Pauli Z operator?
#
#
# - **A.** `p = Pauli('2Z')`
# - **B.** `p = Pauli(QuantumCircuit(1).z(0))`
# - **C.** `p = Pauli('ZY') @ Pauli('Y')`
# - **D.** `p = Pauli('Z')`

# %%
# Optional scratch cell for Question Q025
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.quantum_info import Pauli

p = Pauli("Z")
print(p)
print(p.to_matrix())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `Pauli('Z')` is the direct Pauli-label constructor for the one-qubit Z operator. The other fragments use invalid labels or invalid object shapes.
#
# **Choice review**
#
# - **A: Not correct.** `2Z` is not a valid Pauli label; labels are composed of Pauli characters such as I, X, Y, and Z. _Choice text:_ `p = Pauli('2Z')`
# - **B: Not correct.** The Pauli constructor does not take the return value of a circuit gate call as a Pauli specification. _Choice text:_ `p = Pauli(QuantumCircuit(1).z(0))`
# - **C: Not correct.** This expression composes multi-qubit Paulis and does not directly construct the requested one-qubit Z operator. _Choice text:_ `p = Pauli('ZY') @ Pauli('Y')`
# - **D: Correct.** `Pauli('Z')` is the direct Pauli-label constructor for the one-qubit Z operator. The other fragments use invalid labels or invalid object shapes. _Choice text:_ `p = Pauli('Z')`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli)
#
# </details>

# %% [markdown]
# ### Question 26
#
#
# A transpiler fence is needed between two groups of gates. Which circuit call expresses that boundary?
#
#
# - **A.** `qc.section()`
# - **B.** `qc.session()`
# - **C.** `qc.barrier()`
# - **D.** `qc.partition()`

# %%
# Optional scratch cell for Question Q026
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)
qc.h(0)
qc.barrier()
qc.x(0)
qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# `barrier()` inserts a circuit instruction that constrains movement across that boundary during transpilation.
#
# **Choice review**
#
# - **A: Not correct.** That is not the circuit instruction used as a transpiler boundary. The boundary instruction is `qc.barrier()`. _Choice text:_ `qc.section()`
# - **B: Not correct.** That is not the circuit instruction used as a transpiler boundary. The boundary instruction is `qc.barrier()`. _Choice text:_ `qc.session()`
# - **C: Correct.** `barrier()` inserts a circuit instruction that constrains movement across that boundary during transpilation. _Choice text:_ `qc.barrier()`
# - **D: Not correct.** That is not the circuit instruction used as a transpiler boundary. The boundary instruction is `qc.barrier()`. _Choice text:_ `qc.partition()`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
# - [https://quantum.cloud.ibm.com/docs/en/guides/transpiler-stages](https://quantum.cloud.ibm.com/docs/en/guides/transpiler-stages)
#
# </details>

# %% [markdown]
# ### Question 27
#
#
# The diagram below omits the row names. In Qiskit Runtime Estimator broadcasting terminology, what is row B called?
#
# ![Question figure](../assets/visuals/broadcasting_panels.png)
#
#
# - **A.** Broadcast single observable
# - **B.** Zip
# - **C.** Outer/Product
# - **D.** Standard n-D generalization

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Row B shows equal one-dimensional parameter and observable arrays paired item-by-item. In the Runtime primitive input reference, that pattern is called `Zip`.
#
# **Choice review**
#
# - **A: Not correct.** That name belongs to row A, where one scalar observable is broadcast across several parameter values. _Choice text:_ Broadcast single observable
# - **B: Correct.** Row B shows equal one-dimensional parameter and observable arrays paired item-by-item. In the Runtime primitive input reference, that pattern is called `Zip`. _Choice text:_ Zip
# - **C: Not correct.** That name belongs to row C, where singleton dimensions expand to form a product-shaped result. _Choice text:_ Outer/Product
# - **D: Not correct.** That name belongs to row D, where the same broadcasting idea is shown with higher-rank compatible arrays. _Choice text:_ Standard n-D generalization
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 28
#
#
# `pubs` is a list of Estimator PUBs. Which line submits them?
#
#
# - **A.** `job = estimator.run(pubs)`
# - **B.** `job = estimator.compute(pubs)`
# - **C.** `job = estimator.execute(pubs)`
# - **D.** `job = estimator.evaluate(pubs)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# EstimatorV2 submits primitive work with `run(...)`.
#
# **Choice review**
#
# - **A: Correct.** EstimatorV2 submits primitive work with `run(...)`. _Choice text:_ `job = estimator.run(pubs)`
# - **B: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ `job = estimator.compute(pubs)`
# - **C: Not correct.** A transpiler pass is not executed directly with `.execute(qc)` in this workflow; wrap the pass in a `PassManager` and call `.run(qc)`. _Choice text:_ `job = estimator.execute(pubs)`
# - **D: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ `job = estimator.evaluate(pubs)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 29
#
#
# Which object shape best represents a Runtime primitive unified bloc?
#
#
# - **A.** A list of gates appended directly to a circuit
# - **B.** A pair containing only an observable and a backend name
# - **C.** A REST-only JSON object that the Python SDK never uses
# - **D.** A tuple-like workload unit that includes a circuit and data associated with that circuit

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# A PUB is the primitive workload unit. It organizes a circuit with associated data such as observables or parameter values.
#
# **Choice review**
#
# - **A: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ A list of gates appended directly to a circuit
# - **B: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ A pair containing only an observable and a backend name
# - **C: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ A REST-only JSON object that the Python SDK never uses
# - **D: Correct.** A PUB is the primitive workload unit. It organizes a circuit with associated data such as observables or parameter values. _Choice text:_ A tuple-like workload unit that includes a circuit and data associated with that circuit
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 30
#
#
# Dynamical decoupling is enabled for a scheduled circuit. Which error source is it meant to suppress?
#
#
# - **A.** REST authentication failures
# - **B.** Incorrect Python imports
# - **C.** Idle/decoherence effects during gaps
# - **D.** Readout assignment errors only

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Dynamical decoupling inserts sequences during idle periods to suppress decoherence-related effects.
#
# **Choice review**
#
# - **A: Not correct.** Runtime REST authentication uses the HTTP `Authorization` header with a Bearer token, not URL parameters, JSON body fields, or an unrelated HTTP method header. _Choice text:_ REST authentication failures
# - **B: Not correct.** Python import errors are local programming errors, not the idle/decoherence error source targeted by dynamical decoupling. _Choice text:_ Incorrect Python imports
# - **C: Correct.** Dynamical decoupling inserts sequences during idle periods to suppress decoherence-related effects. _Choice text:_ Idle/decoherence effects during gaps
# - **D: Not correct.** Readout assignment errors happen at measurement; dynamical decoupling targets idle/decoherence effects during scheduled gaps. _Choice text:_ Readout assignment errors only
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques](https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-sampler-options)
#
# </details>

# %% [markdown]
# ### Question 31
#
#
# A mitigation setting randomizes circuit-level operations so coherent errors are converted into easier-to-average stochastic behavior. Which workload element is being randomized?
#
#
# - **A.** The local Python module cache
# - **B.** Gates or measurements in the submitted circuits
# - **C.** Runtime job tags
# - **D.** Session IDs

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Twirling acts on circuit-level gates and/or measurements as supported by primitive options. Metadata, sessions, and local imports are not twirled.
#
# **Choice review**
#
# - **A: Not correct.** Twirling randomizes circuit-level operations or measurements; it does not randomize metadata, session identifiers, or local Python state. _Choice text:_ The local Python module cache
# - **B: Correct.** Twirling acts on circuit-level gates and/or measurements as supported by primitive options. Metadata, sessions, and local imports are not twirled. _Choice text:_ Gates or measurements in the submitted circuits
# - **C: Not correct.** Twirling randomizes circuit-level operations or measurements; it does not randomize metadata, session identifiers, or local Python state. _Choice text:_ Runtime job tags
# - **D: Not correct.** Twirling randomizes circuit-level operations or measurements; it does not randomize metadata, session identifiers, or local Python state. _Choice text:_ Session IDs
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options)
# - [https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques](https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques)
#
# </details>

# %% [markdown]
# ### Question 32
#
#
# **Select 2.**
#
# Which Python objects are valid inputs for `plot_distribution`?
#
#
# - [ ] **A.** `{0: [500, 250], 1: [500, 750]}`
# - [ ] **B.** `[(0, 500), (3, 500)]`
# - [ ] **C.** `[0, 1, 2], [500, 250, 250]`
# - [ ] **D.** `{0: 500, 3: 500}`
# - [ ] **E.** `[{0: 500, 3: 500}, {0: 250, 1: 750}]`

# %%
# Optional scratch cell for Question Q032
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.visualization import plot_distribution

plot_distribution([{0: 500, 3: 500}, {0: 250, 1: 750}])

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D, E
#
# `plot_distribution` expects a distribution mapping, or a list of distribution mappings for comparison. Tuple lists and separate x/y arrays are not the expected object shape.
#
# **Choice review**
#
# - **A: Not correct.** This maps a key to a list of values, but `plot_distribution` expects each distribution to be a mapping from outcomes to scalar weights/counts. _Choice text:_ `{0: [500, 250], 1: [500, 750]}`
# - **B: Not correct.** A list of tuples is not the distribution mapping shape expected here; use a dictionary-style mapping. _Choice text:_ `[(0, 500), (3, 500)]`
# - **C: Not correct.** Separate x/y arrays are not the expected `plot_distribution` input shape. _Choice text:_ `[0, 1, 2], [500, 250, 250]`
# - **D: Correct.** `plot_distribution` expects a distribution mapping, or a list of distribution mappings for comparison. Tuple lists and separate x/y arrays are not the expected object shape. _Choice text:_ `{0: 500, 3: 500}`
# - **E: Correct.** `plot_distribution` expects a distribution mapping, or a list of distribution mappings for comparison. Tuple lists and separate x/y arrays are not the expected object shape. _Choice text:_ `[{0: 500, 3: 500}, {0: 250, 1: 750}]`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization](https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization)
#
# </details>

# %% [markdown]
# ### Question 33
#
#
# Which two-operation sequence prepares `|1>` even if the qubit's previous state is unknown?
#
#
# - **A.** `z` followed by `measure`
# - **B.** `reset` followed by `h`
# - **C.** A nonexistent `set_state(1)` instruction
# - **D.** `reset` followed by `x`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `reset` discards the previous state and prepares `|0>`. Applying X then prepares `|1>`.
#
# **Choice review**
#
# - **A: Not correct.** `Z` changes phase; it does not force an unknown qubit into `|1>`, and measurement is not state preparation. _Choice text:_ `z` followed by `measure`
# - **B: Not correct.** `reset` prepares `|0>`, but applying H prepares `|+>`, not `|1>`. _Choice text:_ `reset` followed by `h`
# - **C: Not correct.** `set_state(1)` is not a Qiskit circuit instruction for preparing `|1>`. _Choice text:_ A nonexistent `set_state(1)` instruction
# - **D: Correct.** `reset` discards the previous state and prepares `|0>`. Applying X then prepares `|1>`. _Choice text:_ `reset` followed by `x`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library](https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library)
#
# </details>

# %% [markdown]
# ### Question 34
#
#
# A `StatevectorEstimator` PUB contains a two-parameter circuit, one observable, and three parameter rows:
#
# ```python
# alpha = Parameter('alpha')
# beta = Parameter('beta')
# qc = QuantumCircuit(1)
# qc.ry(alpha, 0)
# qc.rz(beta, 0)
# observable = SparsePauliOp('X')
# values = np.array([[0.0, 0.0], [np.pi / 3, np.pi / 5], [np.pi / 2, np.pi / 7]])
# job = StatevectorEstimator().run([(qc, observable, values)])
# ```
#
#
# - **A.** The job fails because Estimator PUBs cannot contain parameter arrays.
# - **B.** The primitive transpiles the circuit but does not evaluate the observable.
# - **C.** The result contains one expectation-value estimate for each supplied parameter row.
# - **D.** Only the first parameter row is evaluated.

# %%
# Optional scratch cell for Question Q034
# Run this if you want to inspect the relevant Qiskit behavior locally.
import numpy as np
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.primitives import StatevectorEstimator
from qiskit.quantum_info import SparsePauliOp

alpha = Parameter("alpha")
beta = Parameter("beta")
qc = QuantumCircuit(1)
qc.ry(alpha, 0)
qc.rz(beta, 0)
observable = SparsePauliOp("X")
values = np.array([[0.0, 0.0], [np.pi / 3, np.pi / 5], [np.pi / 2, np.pi / 7]])
job = StatevectorEstimator().run([(qc, observable, values)])
print(job.result()[0].data.evs)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Estimator PUBs support parameter broadcasting. Supplying multiple compatible parameter rows produces a corresponding array of expectation-value estimates.
#
# **Choice review**
#
# - **A: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries. _Choice text:_ The job fails because Estimator PUBs cannot contain parameter arrays.
# - **B: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries. _Choice text:_ The primitive transpiles the circuit but does not evaluate the observable.
# - **C: Correct.** Estimator PUBs support parameter broadcasting. Supplying multiple compatible parameter rows produces a corresponding array of expectation-value estimates. _Choice text:_ The result contains one expectation-value estimate for each supplied parameter row.
# - **D: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries. _Choice text:_ Only the first parameter row is evaluated.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 35
#
#
# The circuit below is still symbolic. Which line returns a circuit with `angle` bound to a numeric value?
#
# ```python
# from qiskit import QuantumCircuit
# from qiskit.circuit import Parameter
#
# angle = Parameter('angle')
# qc = QuantumCircuit(1)
# qc.rz(angle, 0)
# ```
#
#
# - **A.** `bound = qc.parameters.assign({angle: 0.75})`
# - **B.** `bound = qc.assign_parameters({angle: 0.75})`
# - **C.** `bound = qc.set_parameters({angle: 0.75})`
# - **D.** `bound = qc.update_parameters({angle: 0.75})`

# %%
# Optional scratch cell for Question Q035
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter

theta = Parameter("theta")
qc = QuantumCircuit(1)
qc.ry(theta, 0)
bound = qc.assign_parameters({theta: 1.25})
bound.draw(output="text")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `QuantumCircuit.assign_parameters` is the circuit method for binding parameter values. The other method paths are not the documented API.
#
# **Choice review**
#
# - **A: Not correct.** This is not the documented `QuantumCircuit` binding API. The circuit-level method is `assign_parameters(...)`. _Choice text:_ `bound = qc.parameters.assign({angle: 0.75})`
# - **B: Correct.** `QuantumCircuit.assign_parameters` is the circuit method for binding parameter values. The other method paths are not the documented API. _Choice text:_ `bound = qc.assign_parameters({angle: 0.75})`
# - **C: Not correct.** This is not the documented `QuantumCircuit` binding API. The circuit-level method is `assign_parameters(...)`. _Choice text:_ `bound = qc.set_parameters({angle: 0.75})`
# - **D: Not correct.** This is not the documented `QuantumCircuit` binding API. The circuit-level method is `assign_parameters(...)`. _Choice text:_ `bound = qc.update_parameters({angle: 0.75})`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 36
#
#
# A state has amplitude only on `|1>`. What relative phase does `TdgGate` apply to that component?
#
#
# - **A.** `exp(-i*pi/4)`
# - **B.** `exp(i*pi/4)`
# - **C.** `exp(i*pi/2)`
# - **D.** `-1`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# `Tdg` is the adjoint of T and applies `exp(-i*pi/4)` to the `|1>` component.
#
# **Choice review**
#
# - **A: Correct.** `Tdg` is the adjoint of T and applies `exp(-i*pi/4)` to the `|1>` component. _Choice text:_ `exp(-i*pi/4)`
# - **B: Not correct.** `Tdg` applies `exp(-i*pi/4)` to the `|1>` component; this option has the wrong phase. _Choice text:_ `exp(i*pi/4)`
# - **C: Not correct.** `Tdg` applies `exp(-i*pi/4)` to the `|1>` component; this option has the wrong phase. _Choice text:_ `exp(i*pi/2)`
# - **D: Not correct.** `Tdg` applies `exp(-i*pi/4)` to the `|1>` component; this option has the wrong phase. _Choice text:_ `-1`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library](https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library)
#
# </details>

# %% [markdown]
# ### Question 37
#
#
# Which expression returns an OpenQASM 3 string for a circuit object named `circuit`?
#
#
# - **A.** `qiskit.qasm3.to_qasm(circuit)`
# - **B.** `qiskit.qasm3.export(circuit)`
# - **C.** `qiskit.qasm3.write_string(circuit)`
# - **D.** `qiskit.qasm3.dumps(circuit)`

# %%
# Optional scratch cell for Question Q037
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit import qasm3

circuit = QuantumCircuit(1, 1)
circuit.h(0)
circuit.measure(0, 0)
print(qasm3.dumps(circuit))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `qiskit.qasm3.dumps` serializes a circuit to an OpenQASM 3 string.
#
# **Choice review**
#
# - **A: Not correct.** `dumps(...)` is the API that returns an OpenQASM 3 string. The other names are not the string-serialization call being tested. _Choice text:_ `qiskit.qasm3.to_qasm(circuit)`
# - **B: Not correct.** `dumps(...)` is the API that returns an OpenQASM 3 string. The other names are not the string-serialization call being tested. _Choice text:_ `qiskit.qasm3.export(circuit)`
# - **C: Not correct.** `dumps(...)` is the API that returns an OpenQASM 3 string. The other names are not the string-serialization call being tested. _Choice text:_ `qiskit.qasm3.write_string(circuit)`
# - **D: Correct.** `qiskit.qasm3.dumps` serializes a circuit to an OpenQASM 3 string. _Choice text:_ `qiskit.qasm3.dumps(circuit)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qasm3](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qasm3)
# - [https://quantum.cloud.ibm.com/docs/en/guides/interoperate-qiskit-qasm3](https://quantum.cloud.ibm.com/docs/en/guides/interoperate-qiskit-qasm3)
#
# </details>

# %% [markdown]
# ### Question 38
#
#
# Which line creates a two-qubit Pauli with Z on qubit 1 and X on qubit 0, using Qiskit's Pauli-label ordering?
#
#
# - **A.** `p = Pauli('ZI')`
# - **B.** `p = Pauli('IX')`
# - **C.** `p = Pauli('ZX')`
# - **D.** `p = Pauli('XZ')`

# %%
# Optional scratch cell for Question Q038
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.quantum_info import Pauli

p = Pauli("ZX")
print(p.to_matrix())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# Qubit 0 is represented by the rightmost Pauli-label character. Therefore X on qubit 0 and Z on qubit 1 is `'ZX'`.
#
# **Choice review**
#
# - **A: Not correct.** This places the Pauli letter on the wrong side of the label or uses the wrong tensor factor. Qiskit labels put qubit 0 at the rightmost character. _Choice text:_ `p = Pauli('ZI')`
# - **B: Not correct.** This places the Pauli letter on the wrong side of the label or uses the wrong tensor factor. Qiskit labels put qubit 0 at the rightmost character. _Choice text:_ `p = Pauli('IX')`
# - **C: Correct.** Qubit 0 is represented by the rightmost Pauli-label character. Therefore X on qubit 0 and Z on qubit 1 is `'ZX'`. _Choice text:_ `p = Pauli('ZX')`
# - **D: Not correct.** This places the Pauli letter on the wrong side of the label or uses the wrong tensor factor. Qiskit labels put qubit 0 at the rightmost character. _Choice text:_ `p = Pauli('XZ')`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli)
#
# </details>

# %% [markdown]
# ### Question 39
#
#
# A submitted Runtime job failed. Which call retrieves the failure text from the job object?
#
#
# - **A.** `job.exception_text()`
# - **B.** `job.error_message()`
# - **C.** `job.get_error()`
# - **D.** `job.retrieve_error()`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `error_message()` is the documented method for retrieving Runtime job error text.
#
# **Choice review**
#
# - **A: Not correct.** That method name is not the Runtime job error-message API. Use `job.error_message()`. _Choice text:_ `job.exception_text()`
# - **B: Correct.** `error_message()` is the documented method for retrieving Runtime job error text. _Choice text:_ `job.error_message()`
# - **C: Not correct.** That method name is not the Runtime job error-message API. Use `job.error_message()`. _Choice text:_ `job.get_error()`
# - **D: Not correct.** That method name is not the Runtime job error-message API. Use `job.error_message()`. _Choice text:_ `job.retrieve_error()`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.BasePrimitiveJob](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.BasePrimitiveJob)
#
# </details>

# %% [markdown]
# ### Question 40
#
#
# Which array is returned by this Pauli object?
#
# ```python
# from qiskit.quantum_info import Pauli
#
# print(Pauli('Y').to_matrix())
# ```
#
#
# - **A.**
#
#     ```text
#     [[0.+0.j 0.-1.j]
#      [0.+1.j 0.+0.j]]
#     ```
# - **B.**
#
#     ```text
#     [[0.+0.j 1.+0.j]
#      [1.+0.j 0.+0.j]]
#     ```
# - **C.**
#
#     ```text
#     [[ 1.+0.j  0.+0.j]
#      [ 0.+0.j -1.+0.j]]
#     ```
# - **D.** A sampled counts dictionary

# %%
# Optional scratch cell for Question Q040
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.quantum_info import Pauli

p = Pauli("Y")
print(p.to_matrix())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# `Pauli('Y').to_matrix()` returns the single-qubit Y matrix with imaginary off-diagonal entries. It does not run a circuit or return counts.
#
# **Choice review**
#
# - **A: Correct.** `Pauli('Y').to_matrix()` returns the single-qubit Y matrix with imaginary off-diagonal entries. It does not run a circuit or return counts.
#
#   Choice text:
#
#     ```text
#     [[0.+0.j 0.-1.j]
#      [0.+1.j 0.+0.j]]
#     ```
# - **B: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries.
#
#   Choice text:
#
#     ```text
#     [[0.+0.j 1.+0.j]
#      [1.+0.j 0.+0.j]]
#     ```
# - **C: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries.
#
#   Choice text:
#
#     ```text
#     [[ 1.+0.j  0.+0.j]
#      [ 0.+0.j -1.+0.j]]
#     ```
# - **D: Not correct.** This is the matrix for a different Pauli operator, or not a Pauli matrix at all. The requested Pauli label determines the exact matrix entries. _Choice text:_ A sampled counts dictionary
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli)
#
# </details>

# %% [markdown]
# ### Question 41
#
#
# A session object has been created but no workload has started yet. Which lifecycle statement is accurate?
#
#
# - **A.** The session has an unlimited active lifetime.
# - **B.** The session can run only Sampler jobs or only Estimator jobs, never both.
# - **C.** The session always closes exactly 10 minutes after construction.
# - **D.** The session starts when its first job starts.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# Runtime session lifecycle is tied to submitted jobs and service-side inactivity/maximum-time limits.
#
# **Choice review**
#
# - **A: Not correct.** Runtime sessions are governed by service-side maximum-time and inactivity limits, not an infinite lifetime. _Choice text:_ The session has an unlimited active lifetime.
# - **B: Not correct.** Runtime sessions are governed by service lifecycle rules and can support primitive workloads; they are not unlimited, fixed to exactly this time, or restricted as stated. _Choice text:_ The session can run only Sampler jobs or only Estimator jobs, never both.
# - **C: Not correct.** Runtime sessions are governed by service lifecycle rules and can support primitive workloads; they are not unlimited, fixed to exactly this time, or restricted as stated. _Choice text:_ The session always closes exactly 10 minutes after construction.
# - **D: Correct.** Runtime session lifecycle is tied to submitted jobs and service-side inactivity/maximum-time limits. _Choice text:_ The session starts when its first job starts.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execution-modes](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
# - [https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session](https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session)
#
# </details>

# %% [markdown]
# ### Question 42
#
#
# Which option path controls the number of randomized circuits/samples used by twirling?
#
#
# - **A.** `estimator.options.twirling.default_shots`
# - **B.** `estimator.options.twirling.enable_gates`
# - **C.** `estimator.options.twirling.num_randomizations`
# - **D.** `estimator.options.twirling.strategy`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# `num_randomizations` controls how many randomized circuits/samples are used for twirling.
#
# **Choice review**
#
# - **A: Not correct.** This twirling option controls a different part of twirling behavior; the count of randomized samples is `num_randomizations`. _Choice text:_ `estimator.options.twirling.default_shots`
# - **B: Not correct.** This twirling option controls a different part of twirling behavior; the count of randomized samples is `num_randomizations`. _Choice text:_ `estimator.options.twirling.enable_gates`
# - **C: Correct.** `num_randomizations` controls how many randomized circuits/samples are used for twirling. _Choice text:_ `estimator.options.twirling.num_randomizations`
# - **D: Not correct.** This twirling option controls a different part of twirling behavior; the count of randomized samples is `num_randomizations`. _Choice text:_ `estimator.options.twirling.strategy`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-twirling-options)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/options-estimator-options)
#
# </details>

# %% [markdown]
# ### Question 43
#
#
# After transpilation, `isa_circuit.layout` is available. Which line maps observables to the same layout before Estimator execution?
#
#
# - **A.** `isa_observables = [isa_circuit.set_layout(op) for op in observables]`
# - **B.** `isa_observables = [op.apply_layout(isa_circuit.layout) for op in observables]`
# - **C.** `isa_observables = [isa_circuit.layout(op) for op in observables]`
# - **D.** `isa_observables = [op(isa_circuit.layout) for op in observables]`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Observables must be mapped through the transpiled circuit layout with `apply_layout(...)` before hardware Estimator execution.
#
# **Choice review**
#
# - **A: Not correct.** `set_layout` is not how observables are mapped after transpilation; apply the circuit layout to each observable. _Choice text:_ `isa_observables = [isa_circuit.set_layout(op) for op in observables]`
# - **B: Correct.** Observables must be mapped through the transpiled circuit layout with `apply_layout(...)` before hardware Estimator execution. _Choice text:_ `isa_observables = [op.apply_layout(isa_circuit.layout) for op in observables]`
# - **C: Not correct.** `layout` is data on the transpiled circuit, not a callable that maps observables by itself. _Choice text:_ `isa_observables = [isa_circuit.layout(op) for op in observables]`
# - **D: Not correct.** The observable object is not called like a function for layout mapping; use `op.apply_layout(isa_circuit.layout)`. _Choice text:_ `isa_observables = [op(isa_circuit.layout) for op in observables]`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware](https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 44
#
#
# Which pair of PUB array shapes is broadcast-compatible under the primitive input rules?
#
#
# - **A.** `(2, 1, 3)` and `(1, 5, 1)`
# - **B.** `(2, 3)` and `(4, 3)`
# - **C.** `(5,)` and `(4,)`
# - **D.** `(2, 0)` and `(2, 3)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Primitive PUB broadcasting follows NumPy-style rules: dimensions match or one side is 1. `(2,1,3)` and `(1,5,1)` broadcast to `(2,5,3)`.
#
# **Choice review**
#
# - **A: Correct.** Primitive PUB broadcasting follows NumPy-style rules: dimensions match or one side is 1. `(2,1,3)` and `(1,5,1)` broadcast to `(2,5,3)`. _Choice text:_ `(2, 1, 3)` and `(1, 5, 1)`
# - **B: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(2, 3)` and `(4, 3)`
# - **C: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(5,)` and `(4,)`
# - **D: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(2, 0)` and `(2, 3)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 45
#
#
# **Select 3.**
#
# A parameterized Estimator workload is packaged as one PUB. Which items can be part of that PUB?
#
#
# - [ ] **A.** The user's API token
# - [ ] **B.** The backend queue position
# - [ ] **C.** A histogram legend
# - [ ] **D.** The quantum circuit
# - [ ] **E.** The observable or observable array
# - [ ] **F.** The parameter-value array

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D, E, F
#
# Estimator PUBs package a circuit with observables and optional parameter values/precision. Credentials, queue data, and plotting labels are not PUB elements.
#
# **Choice review**
#
# - **A: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ The user's API token
# - **B: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ The backend queue position
# - **C: Not correct.** This describes a non-PUB object. A PUB packages primitive workload data around a circuit; it is not a plotting object, credential bundle, queue field, or raw instruction list. _Choice text:_ A histogram legend
# - **D: Correct.** Estimator PUBs package a circuit with observables and optional parameter values/precision. Credentials, queue data, and plotting labels are not PUB elements. _Choice text:_ The quantum circuit
# - **E: Correct.** Estimator PUBs package a circuit with observables and optional parameter values/precision. Credentials, queue data, and plotting labels are not PUB elements. _Choice text:_ The observable or observable array
# - **F: Correct.** Estimator PUBs package a circuit with observables and optional parameter values/precision. Credentials, queue data, and plotting labels are not PUB elements. _Choice text:_ The parameter-value array
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 46
#
#
# Which code fragment completes the logic: measure qubit 1 into classical bit 1, apply X to qubit 2 if that bit is 1, then measure qubit 2 into classical bit 2?
#
#
# - **A.**
#
#     ```python
#     qc.measure(1, 1)
#     if clbits[1] == 1:
#         qc.x(2)
#     qc.measure(2, 2)
#     ```
# - **B.**
#
#     ```python
#     qc.measure(1, 2)
#     with qc.if_test((clbits[2], 1)):
#         qc.x(1)
#     ```
# - **C.**
#
#     ```python
#     qc.measure(1, 1)
#     with qc.if_test((clbits[1], 1)):
#         qc.x(2)
#     qc.measure(2, 2)
#     ```
# - **D.**
#
#     ```python
#     with qc.if_test((clbits[1], 1)):
#         qc.x(2)
#     qc.measure(1, 1)
#     qc.measure(2, 2)
#     ```

# %%
# Optional scratch cell for Question Q046
# Run this if you want to inspect the relevant Qiskit behavior locally.
import numpy as np
from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister

qubits = QuantumRegister(3)
clbits = ClassicalRegister(3)
qc = QuantumCircuit(qubits, clbits)
qc.initialize([np.sqrt(0.2), np.sqrt(0.8)], 0)
qc.barrier()
qc.h(1)
qc.cx(1, 2)
qc.cx(0, 1)
qc.h(0)
qc.barrier()

qc.measure(1, 1)
with qc.if_test((clbits[1], 1)):
    qc.x(2)
qc.measure(0, 0)
with qc.if_test((clbits[0], 1)):
    qc.z(2)
qc.measure(qubits[2], clbits[2])
qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# The measurement must happen before the classical condition is tested, and dynamic circuit control uses `with qc.if_test(...)`, not a Python `if` statement.
#
# **Choice review**
#
# - **A: Not correct.** A Python `if` runs while constructing the circuit; it does not create circuit-time classical feedforward. Qiskit dynamic circuits use control-flow contexts such as `with qc.if_test(...)`.
#
#   Choice text:
#
#     ```python
#     qc.measure(1, 1)
#     if clbits[1] == 1:
#         qc.x(2)
#     qc.measure(2, 2)
#     ```
# - **B: Not correct.** This measures qubit 1 into the wrong classical bit and then drives the wrong conditional branch; the prompt requires qubit 1 into classical bit 1, then X on qubit 2.
#
#   Choice text:
#
#     ```python
#     qc.measure(1, 2)
#     with qc.if_test((clbits[2], 1)):
#         qc.x(1)
#     ```
# - **C: Correct.** The measurement must happen before the classical condition is tested, and dynamic circuit control uses `with qc.if_test(...)`, not a Python `if` statement.
#
#   Choice text:
#
#     ```python
#     qc.measure(1, 1)
#     with qc.if_test((clbits[1], 1)):
#         qc.x(2)
#     qc.measure(2, 2)
#     ```
# - **D: Not correct.** The conditional block appears before the measurement that writes the classical bit being tested, so the feedforward order is wrong.
#
#   Choice text:
#
#     ```python
#     with qc.if_test((clbits[1], 1)):
#         qc.x(2)
#     qc.measure(1, 1)
#     qc.measure(2, 2)
#     ```
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow](https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 47
#
#
# Which use of `QiskitRuntimeService` is intended for listing previously submitted Runtime jobs?
#
#
# - **A.** `service.backend().jobs()` only for a backend named `ibm_foo`
# - **B.** `service.jobs()` with optional filters such as backend, status, or time
# - **C.** `service.jobs()` only after every possible filter is supplied
# - **D.** `service.jobs()` only for the hard-coded last 30 days

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `service.jobs()` lists jobs visible to the account and supports optional filtering. It is not limited to one literal backend name or an always-required filter set.
#
# **Choice review**
#
# - **A: Not correct.** This invents a backend-specific job-list pattern and a literal backend name; `QiskitRuntimeService.jobs()` is the intended service-level listing call. _Choice text:_ `service.backend().jobs()` only for a backend named `ibm_foo`
# - **B: Correct.** `service.jobs()` lists jobs visible to the account and supports optional filtering. It is not limited to one literal backend name or an always-required filter set. _Choice text:_ `service.jobs()` with optional filters such as backend, status, or time
# - **C: Not correct.** `service.jobs()` supports optional filters; it does not require every filter to be supplied. _Choice text:_ `service.jobs()` only after every possible filter is supplied
# - **D: Not correct.** The job-list API is not defined as an unconditional hard-coded 30-day listing; visibility and filters determine what is returned. _Choice text:_ `service.jobs()` only for the hard-coded last 30 days
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/save-jobs](https://quantum.cloud.ibm.com/docs/en/guides/save-jobs)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job)
#
# </details>

# %% [markdown]
# ### Question 48
#
#
# A direct Runtime REST request is made outside the Python SDK. Where should the API token be placed?
#
#
# - **A.** In the HTTP `Authorization` header as a Bearer token
# - **B.** In the URL query string
# - **C.** In the JSON body under `token`
# - **D.** In an HTTP `CONNECT` header

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Bearer-token authentication uses the `Authorization` header. Tokens should not be sent as ordinary URL parameters or unrelated body fields.
#
# **Choice review**
#
# - **A: Correct.** Bearer-token authentication uses the `Authorization` header. Tokens should not be sent as ordinary URL parameters or unrelated body fields. _Choice text:_ In the HTTP `Authorization` header as a Bearer token
# - **B: Not correct.** Runtime REST authentication uses the HTTP `Authorization` header with a Bearer token, not URL parameters, JSON body fields, or an unrelated HTTP method header. _Choice text:_ In the URL query string
# - **C: Not correct.** Runtime REST authentication uses the HTTP `Authorization` header with a Bearer token, not URL parameters, JSON body fields, or an unrelated HTTP method header. _Choice text:_ In the JSON body under `token`
# - **D: Not correct.** Runtime REST authentication uses the HTTP `Authorization` header with a Bearer token, not URL parameters, JSON body fields, or an unrelated HTTP method header. _Choice text:_ In an HTTP `CONNECT` header
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-runtime-rest](https://quantum.cloud.ibm.com/docs/en/api/qiskit-runtime-rest)
#
# </details>

# %% [markdown]
# ### Question 49
#
#
# Which panel matches the qsphere-style state that would be produced by a Bell-like state with populated `|00>` and `|11>` basis states and a relative phase?
#
# ![Question figure](../assets/visuals/qsphere_panels.png)
#
#
# - **A.** Panel A
# - **B.** Panel B
# - **C.** Panel C
# - **D.** Panel D

# %%
# Optional scratch cell for Question Q049
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

qc = QuantumCircuit(2)
qc.h(0)
qc.z(0)
qc.cx(0, 1)
plot_state_qsphere(Statevector.from_instruction(qc))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# The matching panel must show amplitudes on `|00>` and `|11>`. A different pair of basis states, a single basis state, or the wrong relative phase does not match the circuit state.
#
# **Choice review**
#
# - **A: Correct.** The matching panel must show amplitudes on `|00>` and `|11>`. A different pair of basis states, a single basis state, or the wrong relative phase does not match the circuit state. _Choice text:_ Panel A
# - **B: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ Panel B
# - **C: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ Panel C
# - **D: Not correct.** This label uses the wrong qubit ordering or misses one of the control-target flips. Qiskit displays basis labels as highest-index qubit on the left and qubit 0 on the right. _Choice text:_ Panel D
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_state_qsphere](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.visualization.plot_state_qsphere)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization](https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization)
#
# </details>

# %% [markdown]
# ### Question 50
#
#
# Which Qiskit fragment implements the same operations and classical-bit mapping as this OpenQASM 3 program?
#
# ```qasm
# OPENQASM 3.0;
# include "stdgates.inc";
# bit[3] c;
# qubit[3] q;
# h q[1];
# cx q[1], q[2];
# c[2] = measure q[1];
# c[0] = measure q[2];
# ```
#
#
# - **A.**
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(1)
#     qc.cx(1, 2)
#     qc.measure([1, 2], [0, 2])
#     ```
# - **B.**
#
#     ```python
#     qc = QuantumCircuit(2, 2)
#     qc.h(0)
#     qc.cx(0, 1)
#     qc.measure([0, 1], [0, 1])
#     ```
# - **C.**
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(1)
#     qc.cx(1, 2)
#     qc.measure([1, 2], [2, 0])
#     ```
# - **D.**
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(2)
#     qc.cx(2, 1)
#     qc.measure([1, 2], [2, 0])
#     ```

# %%
# Optional scratch cell for Question Q050
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit, qasm3

target_qasm = '''OPENQASM 3.0;
include "stdgates.inc";
bit[3] c;
qubit[3] q;
h q[1];
cx q[1], q[2];
c[2] = measure q[1];
c[0] = measure q[2];'''

print("Target OpenQASM 3:")
print(target_qasm)

qc = QuantumCircuit(3, 3)
qc.h(1)
qc.cx(1, 2)
qc.measure([1, 2], [2, 0])

print("\nQiskit circuit dumped as OpenQASM 3:")
print(qasm3.dumps(qc))
qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# The Qiskit circuit must preserve both the operation order and the measurement destination bits: qubit 1 maps to classical bit 2, and qubit 2 maps to classical bit 0.
#
# **Choice review**
#
# - **A: Not correct.** This swaps the classical destination bits; the OpenQASM program maps qubit 1 to c[2] and qubit 2 to c[0].
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(1)
#     qc.cx(1, 2)
#     qc.measure([1, 2], [0, 2])
#     ```
# - **B: Not correct.** The OpenQASM program declares three qubits and three classical bits, so a two-qubit/two-bit circuit has the wrong register sizes.
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(2, 2)
#     qc.h(0)
#     qc.cx(0, 1)
#     qc.measure([0, 1], [0, 1])
#     ```
# - **C: Correct.** The Qiskit circuit must preserve both the operation order and the measurement destination bits: qubit 1 maps to classical bit 2, and qubit 2 maps to classical bit 0.
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(1)
#     qc.cx(1, 2)
#     qc.measure([1, 2], [2, 0])
#     ```
# - **D: Not correct.** This reverses the qubit roles: the OpenQASM applies H to q[1] and CX from q[1] to q[2].
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(3, 3)
#     qc.h(2)
#     qc.cx(2, 1)
#     qc.measure([1, 2], [2, 0])
#     ```
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/interoperate-qiskit-qasm3](https://quantum.cloud.ibm.com/docs/en/guides/interoperate-qiskit-qasm3)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qasm3](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qasm3)
#
# </details>

# %% [markdown]
# ### Question 51
#
#
# An Estimator PUB uses parameter values with shape `(3, 1, 2)` and observables with shape `(1, 4, 1)`. What shape should the expectation-value array have?
#
#
# - **A.** `(12, 2)`
# - **B.** `(3, 4, 2)`
# - **C.** `(4, 3, 2)`
# - **D.** `(3, 1, 1)`

# %%
# Optional scratch cell for Question Q051
# Run this if you want to inspect the relevant Qiskit behavior locally.
import numpy as np

parameter_values = np.empty((3, 1, 2))
observables = np.empty((1, 4, 1))
print(np.broadcast_shapes(parameter_values.shape, observables.shape))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Primitive result arrays follow NumPy-style broadcasting. The dimensions combine as `(3,1,2)` with `(1,4,1)` to produce `(3,4,2)`.
#
# **Choice review**
#
# - **A: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(12, 2)`
# - **B: Correct.** Primitive result arrays follow NumPy-style broadcasting. The dimensions combine as `(3,1,2)` with `(1,4,1)` to produce `(3,4,2)`. _Choice text:_ `(3, 4, 2)`
# - **C: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(4, 3, 2)`
# - **D: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ `(3, 1, 1)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 52
#
#
# A notebook process exits after submitting a Runtime job. Later, the user still has the job ID and account access. What is the expected retrieval model?
#
#
# - **A.** The job record can be looked up later through Runtime job/service APIs, subject to access and retention limits.
# - **B.** The result is lost unless the original notebook called `job.save()` before exiting.
# - **C.** The result can be read only from the Python object that originally submitted the job.
# - **D.** The SDK cannot retrieve stored results; only direct REST calls can.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Runtime jobs are service-side records. The SDK can retrieve visible jobs and their results later, within account and retention constraints.
#
# **Choice review**
#
# - **A: Correct.** Runtime jobs are service-side records. The SDK can retrieve visible jobs and their results later, within account and retention constraints. _Choice text:_ The job record can be looked up later through Runtime job/service APIs, subject to access and retention limits.
# - **B: Not correct.** Runtime jobs are service-side records; retrieving them later does not depend on a local `job.save()` call. _Choice text:_ The result is lost unless the original notebook called `job.save()` before exiting.
# - **C: Not correct.** The result is not limited to the original Python process. The service can look up accessible jobs later by ID/API. _Choice text:_ The result can be read only from the Python object that originally submitted the job.
# - **D: Not correct.** The SDK exposes service/job APIs for retrieving stored Runtime job information; direct REST is not the only route. _Choice text:_ The SDK cannot retrieve stored results; only direct REST calls can.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/save-jobs](https://quantum.cloud.ibm.com/docs/en/guides/save-jobs)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job)
#
# </details>

# %% [markdown]
# ### Question 53
#
#
# Which line creates a four-qubit Pauli operator with `Y` on qubit 0 and identity on qubits 1, 2, and 3?
#
#
# - **A.** `p = Pauli('YIII')`
# - **B.** `p = Pauli('IIYI')`
# - **C.** `p = Pauli('Y')`
# - **D.** `p = Pauli('IIIY')`

# %%
# Optional scratch cell for Question Q053
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.quantum_info import Pauli

for label in ["IIIY", "YIII", "IIYI", "Y"]:
    p = Pauli(label)
    print(label, "num_qubits =", p.num_qubits, "x =", p.x.tolist(), "z =", p.z.tolist())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# Qiskit Pauli labels are ordered with qubit 0 at the rightmost character. A four-qubit operator with only Y on qubit 0 is therefore `Pauli('IIIY')`.
#
# **Choice review**
#
# - **A: Not correct.** This places the Pauli letter on the wrong side of the label or uses the wrong tensor factor. Qiskit labels put qubit 0 at the rightmost character. _Choice text:_ `p = Pauli('YIII')`
# - **B: Not correct.** This places the Pauli letter on the wrong side of the label or uses the wrong tensor factor. Qiskit labels put qubit 0 at the rightmost character. _Choice text:_ `p = Pauli('IIYI')`
# - **C: Not correct.** `Pauli('Y')` creates a one-qubit operator. The prompt asks for a four-qubit operator with identities on the other three qubits. _Choice text:_ `p = Pauli('Y')`
# - **D: Correct.** Qiskit Pauli labels are ordered with qubit 0 at the rightmost character. A four-qubit operator with only Y on qubit 0 is therefore `Pauli('IIIY')`. _Choice text:_ `p = Pauli('IIIY')`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Pauli)
#
# </details>

# %% [markdown]
# ### Question 54
#
#
# Which panel could be produced by `plot_histogram([ideal_counts, hardware_counts])` when the ideal simulator is mostly `00` and the hardware result has visible counts in both `00` and `11`?
#
# ![Question figure](../assets/visuals/histogram_panels.png)
#
#
# - **A.** Panel A
# - **B.** Panel B
# - **C.** Panel C
# - **D.** Panel D

# %%
# Optional scratch cell for Question Q054
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.visualization import plot_histogram

ideal_counts = {"00": 900, "11": 100}
hardware_counts = {"00": 560, "11": 440}
plot_histogram([ideal_counts, hardware_counts], legend=["ideal", "hardware"])

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# The correct histogram panel shows two distributions on the same bitstring labels. State plots and single-distribution charts would not compare simulator and hardware counts in one histogram.
#
# **Choice review**
#
# - **A: Correct.** The correct histogram panel shows two distributions on the same bitstring labels. State plots and single-distribution charts would not compare simulator and hardware counts in one histogram. _Choice text:_ Panel A
# - **B: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel B
# - **C: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel C
# - **D: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel D
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization](https://quantum.cloud.ibm.com/docs/en/api/qiskit/visualization)
#
# </details>

# %% [markdown]
# ### Question 55
#
#
# A Runtime job is still active and should be stopped. Which line requests that action?
#
#
# - **A.** `job.in_final_state()`
# - **B.** `job.cancel()`
# - **C.** `job.complete()`
# - **D.** `job.done()`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `cancel()` requests cancellation. The status-style calls do not request that the remote job stop.
#
# **Choice review**
#
# - **A: Not correct.** This checks or suggests status; it does not request cancellation. `job.cancel()` is the cancellation call. _Choice text:_ `job.in_final_state()`
# - **B: Correct.** `cancel()` requests cancellation. The status-style calls do not request that the remote job stop. _Choice text:_ `job.cancel()`
# - **C: Not correct.** This checks or suggests status; it does not request cancellation. `job.cancel()` is the cancellation call. _Choice text:_ `job.complete()`
# - **D: Not correct.** This checks or suggests status; it does not request cancellation. `job.cancel()` is the cancellation call. _Choice text:_ `job.done()`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.BasePrimitiveJob](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.primitives.BasePrimitiveJob)
#
# </details>

# %% [markdown]
# ### Question 56
#
#
# A Runtime workload has classical orchestration plus QPU execution. Which processing statement is accurate?
#
#
# - **A.** Some classical job processing can overlap, while QPU execution is still governed by hardware scheduling.
# - **B.** Runtime jobs skip classical processing entirely.
# - **C.** A QPU executes independent jobs simultaneously by putting jobs in superposition.
# - **D.** Putting every circuit into one huge job is always the fastest strategy.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# Runtime includes classical orchestration and quantum execution. Batching choices depend on workload shape; one giant job is not universally optimal.
#
# **Choice review**
#
# - **A: Correct.** Runtime includes classical orchestration and quantum execution. Batching choices depend on workload shape; one giant job is not universally optimal. _Choice text:_ Some classical job processing can overlap, while QPU execution is still governed by hardware scheduling.
# - **B: Not correct.** Runtime jobs include classical orchestration around quantum execution; they do not skip classical processing entirely. _Choice text:_ Runtime jobs skip classical processing entirely.
# - **C: Not correct.** Independent jobs are scheduled workloads, not quantum states that a QPU executes in superposition. _Choice text:_ A QPU executes independent jobs simultaneously by putting jobs in superposition.
# - **D: Not correct.** Batching everything into one large job is not universally optimal; the best shape depends on queueing, execution mode, and workload structure. _Choice text:_ Putting every circuit into one huge job is always the fastest strategy.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execution-modes](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
# - [https://quantum.cloud.ibm.com/docs/en/guides/choose-execution-mode](https://quantum.cloud.ibm.com/docs/en/guides/choose-execution-mode)
#
# </details>

# %% [markdown]
# ### Question 57
#
#
# A circuit has already been transpiled to ISA form. Which call uses the Sampler v2 input shape?
#
#
# - **A.** `job = sampler.run(isa_circuit, SparsePauliOp('Z'))`
# - **B.** `job = sampler.run(backend, isa_circuit)`
# - **C.** `job = sampler.run(circuit=isa_circuit, mode=backend)`
# - **D.** `job = sampler.run([isa_circuit])`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `SamplerV2.run` accepts an iterable of Sampler PUBs. Observables are Estimator inputs, and the backend is configured by the primitive mode.
#
# **Choice review**
#
# - **A: Not correct.** Observables are Estimator inputs, not Sampler inputs. Sampler v2 receives sampler PUBs such as circuits or circuit tuples. _Choice text:_ `job = sampler.run(isa_circuit, SparsePauliOp('Z'))`
# - **B: Not correct.** The backend belongs in the primitive's `mode`, not as a positional or keyword input to `SamplerV2.run(...)`. _Choice text:_ `job = sampler.run(backend, isa_circuit)`
# - **C: Not correct.** The backend belongs in the primitive's `mode`, not as a positional or keyword input to `SamplerV2.run(...)`. _Choice text:_ `job = sampler.run(circuit=isa_circuit, mode=backend)`
# - **D: Correct.** `SamplerV2.run` accepts an iterable of Sampler PUBs. Observables are Estimator inputs, and the backend is configured by the primitive mode. _Choice text:_ `job = sampler.run([isa_circuit])`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 58
#
#
# A circuit must measure `q[0]` into `c[0]`, then apply `X` to `q[1]` only when that measured bit is 1. Which fragment uses Qiskit's dynamic-circuit API correctly?
#
# ```python
# from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister
#
# q = QuantumRegister(2, 'q')
# c = ClassicalRegister(1, 'c')
# ```
#
#
# - **A.**
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     with qc.if_test((c[0], 1)):
#         qc.x(q[1])
#     ```
# - **B.**
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     if c[0] == 1:
#         qc.x(q[1])
#     ```
# - **C.**
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     with qc.if_test((c[0], 1)):
#         qc.x(q[1])
#     ```
# - **D.**
#
#     ```python
#     qc = DynamicCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     if qc.test((c[0], 1)):
#         qc.x(q[1])
#     ```

# %%
# Optional scratch cell for Question Q058
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister

q = QuantumRegister(2, "q")
c = ClassicalRegister(1, "c")
qc = QuantumCircuit(q, c)
qc.h(q[0])
qc.measure(q[0], c[0])
with qc.if_test((c[0], 1)):
    qc.x(q[1])

qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C
#
# The measured classical bit must exist before the circuit-time condition is evaluated. Qiskit uses `QuantumCircuit` plus `with qc.if_test((c[0], 1)):`; `DynamicCircuit` and Python `if` are distractors.
#
# **Choice review**
#
# - **A: Not correct.** The condition is tested before the relevant classical bit has been written by a measurement, so it does not implement the requested feedforward.
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     with qc.if_test((c[0], 1)):
#         qc.x(q[1])
#     ```
# - **B: Not correct.** A Python `if` runs while constructing the circuit; it does not create circuit-time classical feedforward. Qiskit dynamic circuits use control-flow contexts such as `with qc.if_test(...)`.
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     if c[0] == 1:
#         qc.x(q[1])
#     ```
# - **C: Correct.** The measured classical bit must exist before the circuit-time condition is evaluated. Qiskit uses `QuantumCircuit` plus `with qc.if_test((c[0], 1)):`; `DynamicCircuit` and Python `if` are distractors.
#
#   Choice text:
#
#     ```python
#     qc = QuantumCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     with qc.if_test((c[0], 1)):
#         qc.x(q[1])
#     ```
# - **D: Not correct.** `DynamicCircuit` is not the Qiskit class used here; dynamic control flow is built with `QuantumCircuit` methods such as `if_test`, `switch`, and loop builders.
#
#   Choice text:
#
#     ```python
#     qc = DynamicCircuit(q, c)
#     qc.h(q[0])
#     qc.measure(q[0], c[0])
#     if qc.test((c[0], 1)):
#         qc.x(q[1])
#     ```
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow](https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 59
#
#
# Why is broadcasting useful when building Estimator PUBs?
#
#
# - **A.** It creates a new Runtime session for each parameter value.
# - **B.** It combines compatible observable and parameter arrays without manually writing every pair.
# - **C.** It decomposes two-qubit gates into the backend basis.
# - **D.** It increases the number of shots automatically.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Broadcasting is array-shape behavior for primitive inputs. It does not transpile gates, allocate shots, or create sessions.
#
# **Choice review**
#
# - **A: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ It creates a new Runtime session for each parameter value.
# - **B: Correct.** Broadcasting is array-shape behavior for primitive inputs. It does not transpile gates, allocate shots, or create sessions. _Choice text:_ It combines compatible observable and parameter arrays without manually writing every pair.
# - **C: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ It decomposes two-qubit gates into the backend basis.
# - **D: Not correct.** This shape does not follow NumPy-style broadcasting for the dimensions in the prompt. Matching dimensions or singleton dimensions expand; other dimensions do not. _Choice text:_ It increases the number of shots automatically.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output](https://quantum.cloud.ibm.com/docs/en/guides/primitive-input-output)
#
# </details>

# %% [markdown]
# ### Question 60
#
#
# After this one-qubit circuit is built, which state has been prepared?
#
# ```python
# from qiskit import QuantumCircuit
#
# qc = QuantumCircuit(1)
# qc.reset(0)
# qc.x(0)
# qc.h(0)
# ```
#
#
# - **A.** |->
# - **B.** |0>
# - **C.** |1>
# - **D.** |+>

# %%
# Optional scratch cell for Question Q060
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(1)
qc.reset(0)
qc.x(0)
qc.h(0)
state = Statevector.from_instruction(qc)
print(state)
print(state.probabilities_dict())

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# `reset` prepares `|0>`. The following gates determine the final state: H on `|0>` gives `|+>`, X gives `|1>`, and H on `|1>` gives `|->`.
#
# **Choice review**
#
# - **A: Correct.** `reset` prepares `|0>`. The following gates determine the final state: H on `|0>` gives `|+>`, X gives `|1>`, and H on `|1>` gives `|->`. _Choice text:_ |->
# - **B: Not correct.** This state does not match the reset-plus-gate sequence in the prompt; track `reset` first, then the following gate. _Choice text:_ |0>
# - **C: Not correct.** This state does not match the reset-plus-gate sequence in the prompt; track `reset` first, then the following gate. _Choice text:_ |1>
# - **D: Not correct.** This state does not match the reset-plus-gate sequence in the prompt; track `reset` first, then the following gate. _Choice text:_ |+>
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library](https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library)
#
# </details>

# %% [markdown]
# ### Question 61
#
#
# What is the approximate probability of measuring bit value 1 after this circuit?
#
# ```python
# from qiskit import QuantumCircuit
# import numpy as np
#
# qc = QuantumCircuit(1)
# qc.reset(0)
# qc.rx(2 * np.pi / 3, 0)
# qc.measure_all()
# ```
#
#
# - **A.** `0.25`
# - **B.** `0.50`
# - **C.** `1.00`
# - **D.** `0.75`

# %%
# Optional scratch cell for Question Q061
# Run this if you want to inspect the relevant Qiskit behavior locally.
import numpy as np

theta = 2 * np.pi / 3
print("P(0) =", np.cos(theta / 2) ** 2)
print("P(1) =", np.sin(theta / 2) ** 2)

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# For `RX(theta)|0>`, the probability of measuring 1 is `sin^2(theta/2)`. With `theta = 2*pi/3`, this is `sin^2(pi/3) = 0.75`.
#
# **Choice review**
#
# - **A: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RX(theta)|0>`, the probability of measuring 1 is `sin^2(theta/2)`. With `theta = 2*pi/3`, this is `sin^2(pi/3) = 0.75`. _Choice text:_ `0.25`
# - **B: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RX(theta)|0>`, the probability of measuring 1 is `sin^2(theta/2)`. With `theta = 2*pi/3`, this is `sin^2(pi/3) = 0.75`. _Choice text:_ `0.50`
# - **C: Not correct.** This is the wrong probability for the stated rotation. The tested relationship is: For `RX(theta)|0>`, the probability of measuring 1 is `sin^2(theta/2)`. With `theta = 2*pi/3`, this is `sin^2(pi/3) = 0.75`. _Choice text:_ `1.00`
# - **D: Correct.** For `RX(theta)|0>`, the probability of measuring 1 is `sin^2(theta/2)`. With `theta = 2*pi/3`, this is `sin^2(pi/3) = 0.75`. _Choice text:_ `0.75`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library](https://quantum.cloud.ibm.com/docs/en/api/qiskit/circuit_library)
#
# </details>

# %% [markdown]
# ### Question 62
#
#
# **Select 2.**
#
# In a circuit-control code review, which two names are actual `QuantumCircuit` control-flow builders?
#
#
# - [ ] **A.** `QuantumCircuit.repeat_until(...)`
# - [ ] **B.** `QuantumCircuit.replace(...)`
# - [ ] **C.** `QuantumCircuit.branch(...)`
# - [ ] **D.** `QuantumCircuit.while_loop(...)`
# - [ ] **E.** `QuantumCircuit.for_loop(...)`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D, E
#
# `while_loop` and `for_loop` are documented circuit control-flow builders. The other names are plausible but are not the tested Qiskit v2.x API.
#
# **Choice review**
#
# - **A: Not correct.** That is not one of the `QuantumCircuit` control-flow builders tested here. The valid builders in this question are `while_loop(...)` and `for_loop(...)`. _Choice text:_ `QuantumCircuit.repeat_until(...)`
# - **B: Not correct.** That is not one of the `QuantumCircuit` control-flow builders tested here. The valid builders in this question are `while_loop(...)` and `for_loop(...)`. _Choice text:_ `QuantumCircuit.replace(...)`
# - **C: Not correct.** That is not one of the `QuantumCircuit` control-flow builders tested here. The valid builders in this question are `while_loop(...)` and `for_loop(...)`. _Choice text:_ `QuantumCircuit.branch(...)`
# - **D: Correct.** `while_loop` and `for_loop` are documented circuit control-flow builders. The other names are plausible but are not the tested Qiskit v2.x API. _Choice text:_ `QuantumCircuit.while_loop(...)`
# - **E: Correct.** `while_loop` and `for_loop` are documented circuit control-flow builders. The other names are plausible but are not the tested Qiskit v2.x API. _Choice text:_ `QuantumCircuit.for_loop(...)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow](https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.QuantumCircuit)
#
# </details>

# %% [markdown]
# ### Question 63
#
#
# Several Runtime jobs appear in a dashboard with the same `session_id`. What does that ID indicate?
#
#
# - **A.** Those jobs are automatically first in the backend queue.
# - **B.** Those jobs are associated with the same Runtime session.
# - **C.** Those jobs must have used the same physical qubit layout.
# - **D.** Those jobs share the user's API token.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# `session_id` groups jobs by Runtime session. It is not a backend-layout, authentication, or queue-priority field.
#
# **Choice review**
#
# - **A: Not correct.** `session_id` groups jobs by Runtime session. It does not encode queue priority, layout, or authentication. _Choice text:_ Those jobs are automatically first in the backend queue.
# - **B: Correct.** `session_id` groups jobs by Runtime session. It is not a backend-layout, authentication, or queue-priority field. _Choice text:_ Those jobs are associated with the same Runtime session.
# - **C: Not correct.** `session_id` groups jobs by Runtime session. It does not encode queue priority, layout, or authentication. _Choice text:_ Those jobs must have used the same physical qubit layout.
# - **D: Not correct.** `session_id` groups jobs by Runtime session. It does not encode queue priority, layout, or authentication. _Choice text:_ Those jobs share the user's API token.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session](https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job](https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/runtime-job)
#
# </details>

# %% [markdown]
# ### Question 64
#
#
# What does the final line print?
#
# ```python
# from qiskit.circuit import ParameterVector
#
# weights = ParameterVector('w', 5)
# selected = weights[3]
# print(weights.index(selected))
# ```
#
#
# - **A.** `3`
# - **B.** `w[3]`
# - **C.** `4`
# - **D.** `ParameterVectorElement(3)`

# %%
# Optional scratch cell for Question Q064
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit.circuit import ParameterVector

v = ParameterVector("v", 3)
x = v[1]
print(v.index(x))

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# `ParameterVector` behaves like a sequence, and Python sequence indexes are zero-based. The element at `weights[3]` has index 3.
#
# **Choice review**
#
# - **A: Correct.** `ParameterVector` behaves like a sequence, and Python sequence indexes are zero-based. The element at `weights[3]` has index 3. _Choice text:_ `3`
# - **B: Not correct.** The question asks for the zero-based sequence index. `weights[3]` has index `3`, not a display name or a one-based position. _Choice text:_ `w[3]`
# - **C: Not correct.** The question asks for the zero-based sequence index. `weights[3]` has index `3`, not a display name or a one-based position. _Choice text:_ `4`
# - **D: Not correct.** The question asks for the zero-based sequence index. `weights[3]` has index `3`, not a display name or a one-based position. _Choice text:_ `ParameterVectorElement(3)`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.Parameter)
# - [https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.ParameterExpression](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.circuit.ParameterExpression)
#
# </details>

# %% [markdown]
# ### Question 65
#
#
# Which line retrieves a backend object from a `QiskitRuntimeService` named `service`?
#
#
# - **A.** `backend = service.fetch_backend("ibm_test_backend")`
# - **B.** `backend = service.get("ibm_test_backend")`
# - **C.** `backend = "ibm_test_backend"`
# - **D.** `backend = service.backend("ibm_test_backend")`

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** D
#
# `service.backend(name)` returns a backend object by name. A plain string is not a backend object.
#
# **Choice review**
#
# - **A: Not correct.** That is not the SDK call for retrieving a named backend from `QiskitRuntimeService`; use `service.backend(name)`. _Choice text:_ `backend = service.fetch_backend("ibm_test_backend")`
# - **B: Not correct.** That is not the SDK call for retrieving a named backend from `QiskitRuntimeService`; use `service.backend(name)`. _Choice text:_ `backend = service.get("ibm_test_backend")`
# - **C: Not correct.** A string stores only the backend name. Runtime primitives need the backend object returned by the service. _Choice text:_ `backend = "ibm_test_backend"`
# - **D: Correct.** `service.backend(name)` returns a backend object by name. A plain string is not a backend object. _Choice text:_ `backend = service.backend("ibm_test_backend")`
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware](https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 66
#
#
# **Order the options.**
#
# Put these Estimator workflow steps in the correct order for a hardware-oriented run.
#
#
# - **A.** Create the Estimator primitive in the selected execution mode.
# - **B.** Submit the PUBs with estimator.run(...) and retrieve the result.
# - **C.** Define the quantum circuit and observable operator.
# - **D.** Transpile the circuit to the target ISA and apply the layout to the observables.

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** C, D, A, B
#
# The circuit and observables must exist first. Hardware-oriented workflows then transpile the circuit to the backend ISA and map observables through the resulting layout. Only after the inputs are compatible should the Estimator be constructed/submitted and the result retrieved. With the shuffled choices shown here, the correct order is C, D, A, B.
#
# **Choice review**
#
# - **A: Step 3.** _Choice text:_ Create the Estimator primitive in the selected execution mode.
# - **B: Step 4.** _Choice text:_ Submit the PUBs with estimator.run(...) and retrieve the result.
# - **C: Step 1.** _Choice text:_ Define the quantum circuit and observable operator.
# - **D: Step 2.** _Choice text:_ Transpile the circuit to the target ISA and apply the layout to the observables.
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware](https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware)
# - [https://quantum.cloud.ibm.com/docs/en/guides/primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives)
#
# </details>

# %% [markdown]
# ### Question 67
#
#
# Which setting category is used to bound how much Runtime quantum execution time a workload can consume?
#
#
# - **A.** Only default transpiler settings
# - **B.** Execution-time limits where supported
# - **C.** More shots and more iterations
# - **D.** Long sleeps between submitted jobs

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** B
#
# Execution-time limits are intended to bound Runtime usage. More shots or iterations usually increase runtime.
#
# **Choice review**
#
# - **A: Not correct.** Transpiler defaults do not impose a Runtime usage-time cap. _Choice text:_ Only default transpiler settings
# - **B: Correct.** Execution-time limits are intended to bound Runtime usage. More shots or iterations usually increase runtime. _Choice text:_ Execution-time limits where supported
# - **C: Not correct.** More shots or iterations usually increases execution time rather than bounding it. _Choice text:_ More shots and more iterations
# - **D: Not correct.** Sleeping between submissions does not set a Runtime quantum-time limit. _Choice text:_ Long sleeps between submitted jobs
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware](https://quantum.cloud.ibm.com/docs/en/guides/execute-on-hardware)
# - [https://quantum.cloud.ibm.com/docs/en/guides/execution-modes](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
#
# </details>

# %% [markdown]
# ### Question 68
#
#
# Which circuit drawing panel is produced by the code below?
#
# ```python
# from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister
#
# q = QuantumRegister(2, 'q')
# c = ClassicalRegister(2, 'c')
# qc = QuantumCircuit(q, c)
# qc.h(q[0])
# qc.measure(q[0], c[0])
# with qc.switch(c[0]) as case:
#     with case(0):
#         qc.z(q[1])
#     with case(1):
#         qc.x(q[1])
# qc.measure(q[1], c[1])
# qc.draw(output='mpl')
# ```
#
# ![Question figure](../assets/visuals/dynamic_switch_panels.png)
#
#
# - **A.** Panel A
# - **B.** Panel B
# - **C.** Panel C
# - **D.** Panel D

# %%
# Optional scratch cell for Question Q068
# Run this if you want to inspect the relevant Qiskit behavior locally.
from qiskit import ClassicalRegister, QuantumCircuit, QuantumRegister

q = QuantumRegister(2, "q")
c = ClassicalRegister(2, "c")
qc = QuantumCircuit(q, c)
qc.h(q[0])
qc.measure(q[0], c[0])
with qc.switch(c[0]) as case:
    with case(0):
        qc.z(q[1])
    with case(1):
        qc.x(q[1])
qc.measure(q[1], c[1])
qc.draw(output="mpl")

# %% [markdown]
# <details>
# <summary>Show answer</summary>
#
# **Answer:** A
#
# The matching drawing measures `q[0]` into `c[0]`, switches on that bit, applies Z or X to `q[1]` in the correct cases, and finally measures `q[1]` into `c[1]`.
#
# **Choice review**
#
# - **A: Correct.** The matching drawing measures `q[0]` into `c[0]`, switches on that bit, applies Z or X to `q[1]` in the correct cases, and finally measures `q[1]` into `c[1]`. _Choice text:_ Panel A
# - **B: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel B
# - **C: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel C
# - **D: Not correct.** That panel does not match the visual features requested in the prompt, such as the prepared state, circuit structure, histogram labels, or broadcast shape. _Choice text:_ Panel D
#
# **References**
#
# - [https://quantum.cloud.ibm.com/docs/en/guides/visualize-circuits](https://quantum.cloud.ibm.com/docs/en/guides/visualize-circuits)
# - [https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow](https://quantum.cloud.ibm.com/docs/en/guides/classical-feedforward-and-control-flow)
#
# </details>
