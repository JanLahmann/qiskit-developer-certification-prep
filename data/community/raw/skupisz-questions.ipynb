# %% [markdown]
# 1. The tensor multiplications of A by B can be obtained by the `A.tensor(B)` command. How to perform the tensor multiplication of B by A?
#
# A) `B.tensor(A)`
#
# B) `A.expand(B)`
#
# C) None of the answers above are correct

# %% [markdown]
# 2. How to compute fidelity of two channels?
#
# A) F = channel_fidelity(opA, opB)
#
# B) F  = process_fidelity(opA, opB)
#
# C) F = fidelity(opA, opB)

# %% [markdown]
# 3. Which of the classes below stores linear operators as density matrix?
#
# A) SparsePauliOp
#
# B) Pauli
#
# C) Operator

# %% [markdown]
# 4. Suppose you're visualizing the quantum circuit with text. You want to limit the line length to 50 characters. Which of below would do that?
#
# A) `circuit.draw(output="mpl")`
#
# B) `circuit.draw(output="text", truncate=True, max_width=50)`
#
# C) `circuit.draw(output="text", fold=50)`
#
# D) `circuit.draw(output="text", max_width=50)`

# %% [markdown]
# 5. How would you sort the sampling results of a bell state such that the first value sampled to the left of the visualization is 11 and the rightmost one is 00?
#
# A) `sort="increasing"`
#
# B) `sort="asc"`
#
# C) `order="desc"`
#
# D) `order="decreasing"`
#
# E) None of the above

# %% [markdown]
# 6. You'd like to display a quantum state density matrix in such a way that you see separately real and imaginary amplitudes. What kinds of visualization would you choose?
#
# A) QSphere
#
# B) Bloch Sphere
#
# C) City
#
# D) Hinton
#
# E) LaTex

# %% [markdown]
# 7. You take a look at the transpiled ISA circuit. You see it has no consecutive 1-qubit gates that are the inverses of each other, but you can see the number of qubits are the same as in the original quantum circuit. Furthermore, you see that on one of the qubits there is a number of rotations around the Y axis that could be summed up to one rotation by `π/2` radians. What would you do to fix both of those issues?
#
#
# A) Switch from optimization level 0 to optimization level 1
#
# B) Switch from optimization level 1 to optimization level 2
#
# C) Switch from optimization level 3 to optimization level 2

# %% [markdown]
# 8. You are given a quantum circuit which input, say `k`, is a number of parameters it will consider during the execution. What can you do to optimally create all of the parameters needed?
#
# A) ```
#     parameters=[]
# for i in range (k):
#     newParam = Parameter(f"hi{i}")
#     parameters.append(newParam)
#     ```
#
# B) ```
#     import numpy as np
#     parameters = Parameter(np.arange(0,k))
#     ```
#
# C) ```
#     parameters = ParameterVector("hi", k)
#     ```

# %% [markdown]
# 9. You are given a task to estimate the heat transfer between two parts of a factory. You need to encode the data into the quantum circuit. What kind of qiskit circuit will you use?
#
# A) N-local circuit, imported as `n_local`
#
# B) Data-encoding circuit with the use of `zz_feature_map`
#
# C) Data-encoding circuit with the use of Amplitude Encoding
#
# D) Time-evolution circuit imported as `PauliEvolutionGate`
#
# E) Time-evolution circuit imported as `TimeEvolutionGate`

# %% [markdown]
# 10. Suppose you have a quantum circuit for finding a ground state energy of water. You would like to run this on a IBM quantum machine of your choice. What execution mode would you choose?
#
# A) Batch
#
# B) Job
#
# C) Session
#
# D) None of the above

# %% [markdown]
# 11. Suppose you are given the following piece of code concerning the running of EstimatorV2 :
# `job = estimator.run([(param_values, isa_circuit, isa_observable)])`
#
# Is this piece of code valid?
#
# A) Yes, because PUB has all of the elements
#
# B) Yes, because parameter values are provided
#
# C) No, as the order of the PUB elements is incorrect
#
# D) None of the above

# %% [markdown]
# 12. You are asked to do the estimation of a quantum circuit. The backend you should use is provided by the external provider. You also know this provider implements `Backend` interface. What could you use to create the estimator out in this situation?
#
# A) EstimatorV2
#
# B) EstimatorBackendV2
#
# C) BackendSamplerV2
#
# D) BackendEstimatorV2
#
# E) ExternalEstimator

# %% [markdown]
# 13. Suppose you build a GHZ state circuit for 3 qubits i.e. the state such that after the measurement it will collapse to either |000> or |111>. You choose a backend that has 156 qubits. Then, you transpile the circuit into the ISA one. How many qubits will have the ISA circuit?
#
# A) 3 qubits
#
# B) 153 qubits
#
# C) 156 qubits

# %% [markdown]
# 14. You have a non-parametrized circuit that you want to execute exactly 512 times. Which of the pieces of code below can do this?
#
# A) `job = sampler.run([qc_circuit], shots=512)`
#
# B) `job = sampler.run([qc_circuit, observables, param_values], shots=512)`
#
# C) `job = sampler.run([qc_circuit, param_values], shots=512)`
#
# D) `job = sampler.run([qc_circuit, _, 512])`

# %% [markdown]
# 15. You have the following observables given. You want to group them with `group_commuting` function, so you can compute them from a fingle measurement. However, you want to commute basing on the whole operator, not on a per-qubit basis - how can you do this?
#
# A) `op.group_commuting(group_wise=True)`
#
# B) `op.group_commuting(group_wise=False)`
#
# C) `op.group_commuting(per_qubit=False)`
#
# D) `op.group_commuting(op_as_whole=True)`

# %% [markdown]
# 16. You have the Parameter value set being an array of dimensions (1,4) and the observables array being an array of (10,1) dimensions. What will be the dimensions of the Estimator Broadcasting estimates?
#
# A) 1x1
#
# B) 1x4
#
# C) 10x4
#
# D) 4x10
#
# E) None of the above

# %% [markdown]
# 17. You have a backend of 10 qubits. You want to run a circuit concerning only 1 qubit with an Estimator primitive. You transpiled the circuit and obtained the ISA observable which is `IIIXIIIIII`, `IIIZIIIIII`, with coeffs `[1.+0.j], [1+0.4.j]`. Why is this observable invalid?
#
# A) The number of backend qubits and the original circuit one are incompatible with each other
#
# B) Pauli strings can be composed only from the `I, X and Y` letters
#
# C) Coefficients must be real numbers
#
# D) None of the above

# %% [markdown]
# 18. The quantum circuit has been executed on estimator. You take a look at the first `PubResult` in the array of results. Let's say you store it in the variable named `data`. How can you check the standard error of the mean of expectation value estimates?
#
# A) `data.stde`
#
# B) `data.stds`
#
# C) `data.errors.stds`

# %% [markdown]
# 19. How do you save the job results to the disk with the use of Qiskit and Python?
#
# A) As a text file
#
# B) As a JSON file
#
# C) As an Avro file
#
# D) As an XML file

# %% [markdown]
# 20. Suppose you have a system calling IBM Quantum computers every single day to perform analysis of a chemical molecule. You want to check all of the calls after 1st of April. What parameter of the `service.jobs` function can help you with this?
#
# A) created_after
#
# B) start_time
#
# C) time_interval

# %% [markdown]
# 21. Where can you check your job status?
#
# A) `job.status()` in python program
#
# B) `job.current_state()` in python program
#
# C) In the Workload table on IBM Quantum Platform

# %% [markdown]
# 22. Can you use physical qubits inside the gate statements?
#
# A) Yes
#
# B) No

# %% [markdown]
# 23. You have a custom quantum gate that is constructed in QASM3. Assuming it is stored in a python variable named `special_gate`, how can you convert it to quantum circuit?
#
# A) ``` import qiskit.qasm3
#     qc = qiskit.qasm.convert(special_gate)```
#
# B) ``` qc = qiskit.loads_qasm3(special_gate)```
#
# C) ``` import qiskit.qasm3
#     qc = qiskit.qasm3.loads(special_gate)```

# %% [markdown]
# 24. You want to write a quantum circuit in QASM. You know you will need only the commonly used gates like `X` or `CX`. What should you place at the beginning of your code?
#
# A) Nothing - standard gates are automatically imported
#
# B) `include "stdgates.inc";`
#
# C) `import "stdgates.inc";`
#
# D) `include "standardgates.inc";`

# %% [markdown]
# Answers:
#
# 1) A,B
# 2) B
# 3) C
# 4) C
# 5) C
# 6) A,D
# 7) B
# 8) C
# 9) D
# 10) C
# 11) C
# 12) D
# 13) C
# 14) A
# 15) A
# 16) C
# 17) C
# 18) B
# 19) B
# 20) A
# 21) A,C
# 22) B
# 23) C
# 24) B
